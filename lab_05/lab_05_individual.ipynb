# %% [markdown]
# # STAT 207 Lab Assignment 5 - Individual Part - [24 total points]

# %% [markdown]
# ## <u>Case Study</u>: Predicting Coffee Aroma *for New Coffee Brands*
#
#
#
# ### Coffee Dataset Information
#
# In this individual assignment we will return to the `coffee_top_varieties.csv` dataset. Information about the variables in this dataset can be found here: https://corgis-edu.github.io/corgis/csv/coffee/ Just like in Lab 3, we have pre-filtered for just the most popular varieties of coffee found in the original dataset.
#
#
# ### Research Goals
#
# In this individual assignment we would ideally like to pursue multiple research goals.
#
# #### Main Research Goal
#
# Our main research goal will be to create a predictive model that effectively predicts the `Aroma` of *new coffee brands*.
#
#
# #### Secondary Research Goals
#
# Ideally, the predictive model that we select will also be able to meet the following secondary research goals.
#
# 1. The *type* of predictive model that we choose (ie. a linear regression model) is suitable given our training dataset.
# 2. We can interpret the slopes of this linear regression and trust that these interpretations accurately reflect the relationships that exist between the variables in the training dataset.
#
#
# <p>&nbsp;</p>
# <table style="border: none;border-collapse: collapse;width:102pt;">
#     <tbody>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;width:51pt;">Problem</td>
#             <td style="color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;border-left:none;width:51pt;">Points</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.5</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.6</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.2.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.2.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.4.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.4.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.5.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.5.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.5.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.75</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">6.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.75</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">6.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">7.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">7.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">8.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">8.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">8.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;background:#E7E6E6;height:14.25pt;border-top:none;">Total</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;background:#E7E6E6;border-top:none;border-left:none;">24</td>
#         </tr>
#     </tbody>
# </table>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %% [markdown]
# ## 1. Coffee Dataset
#
# ### 1.1. Reading the csv
#
# 1. Read the `coffee_top_varieties.csv` into a dataframe. The strings that are used to represent missing values in **the numerical columns** of this csv file are represented with 'nan'. Luckily, 'nan' is one of the string values that the **pd.read_csv()** function is automatically programmed to detect as a missing value and thus convert into a NaN type object.
# 2. Show the first 5 rows.
# 3. Show how many rows this dataframe has.

# %%
df = pd.read_csv("C:\\Users\\samma\\Documents\\stat207\\saraza2\\lab_05\\coffee_top_varieties.csv")
df.head()
# Out:
#   Location_Country Location_Region  Location_Altitude_Min  \
# 0           Brazil  south of minas                   1250
# 1           Brazil   vale da grama                   1300
# 2           Brazil  south of minas                   1250
# 3           Brazil  south of minas                   1250
# 4           Brazil  south of minas                   1200
#
#    Location_Altitude_Max  Location_Altitude_Average  Year Data_Owner  \
# 0                   1250                       1250  2011   nucoffee
# 1                   1300                       1300  2011   nucoffee
# 2                   1250                       1250  2011   nucoffee
# 3                   1250                       1250  2011   nucoffee
# 4                   1200                       1200  2011   nucoffee
#
#   Data_Type_Species Data_Type_Variety Data_Type_Processing method  ...  \
# 0           Arabica           Bourbon               Natural / Dry  ...
# 1           Arabica           Bourbon               Natural / Dry  ...
# 2           Arabica           Bourbon   Semi-washed / Semi-pulped  ...
# 3           Arabica           Bourbon   Semi-washed / Semi-pulped  ...
# 4           Arabica           Bourbon               Natural / Dry  ...
#
#    Data_Scores_Flavor  Data_Scores_Aftertaste  Data_Scores_Acidity  \
# 0                8.50                    8.00                 8.00
# 1                8.17                    8.00                 7.75
# 2                8.00                    8.00                 8.00
# 3                8.00                    8.00                 7.67
# 4                7.92                    7.75                 7.75
#
#    Data_Scores_Body  Data_Scores_Balance  Data_Scores_Uniformity  \
# 0              8.00                 8.00                    10.0
# 1              8.00                 8.00                    10.0
# 2              7.75                 8.00                    10.0
# 3              7.75                 8.00                    10.0
# 4              8.00                 7.75                    10.0
#
#    Data_Scores_Sweetness  Data_Scores_Moisture  Data_Scores_Total  Data_Color
# 0                   10.0                  0.12              86.92       Green
# 1                   10.0                  0.12              86.42       Green
# 2                   10.0                  0.11              86.08  Blue-Green
# 3                   10.0                  0.11              85.42  Blue-Green
# 4                   10.0                  0.11              84.92       Green
#
# [5 rows x 23 columns]

# %%
num_rows = len(df)
num_rows
# Out:
# 582

# %% [markdown]
# ### 1.2. Dropping Explicit NaN Values
#
# We only intend to use the `Aroma`, `Flavor`, `Aftertaste`, `Acidity`, `Body`, `Balance`, `Uniformity`, `Sweetness`, `Moisture`, `Color`, and `Variety` variables in this dataframe.
#
# 1. Create a dataframe with just these variables.
# 2. Then drop all rows from this dataframe that have a NaN value.
# 3. How many rows did you drop?

# %%
df_short = df[['Data_Scores_Aroma', 'Data_Scores_Flavor', 'Data_Scores_Aftertaste', 'Data_Scores_Acidity', 'Data_Scores_Body', 'Data_Scores_Balance', 'Data_Scores_Uniformity', 'Data_Scores_Sweetness', 'Data_Scores_Moisture', 'Data_Color', 'Data_Type_Variety']]
df_short
# Out:
#      Data_Scores_Aroma  Data_Scores_Flavor  Data_Scores_Aftertaste  \
# 0                 8.50                8.50                    8.00
# 1                 8.50                8.17                    8.00
# 2                 8.33                8.00                    8.00
# 3                 8.00                8.00                    8.00
# 4                 8.00                7.92                    7.75
# ..                 ...                 ...                     ...
# 577               7.33                7.25                    6.92
# 578               7.33                7.42                    7.33
# 579               7.58                7.00                    6.75
# 580               7.58                7.67                    7.42
# 581               0.00                0.00                    0.00
#
#      Data_Scores_Acidity  Data_Scores_Body  Data_Scores_Balance  \
# 0                   8.00              8.00                 8.00
# 1                   7.75              8.00                 8.00
# 2                   8.00              7.75                 8.00
# 3                   7.67              7.75                 8.00
# 4                   7.75              8.00                 7.75
# ..                   ...               ...                  ...
# 577                 7.33              7.25                 7.33
# 578                 7.42              7.50                 7.42
# 579                 6.92              7.00                 6.92
# 580                 7.42              7.67                 7.67
# 581                 0.00              0.00                 0.00
#
#      Data_Scores_Uniformity  Data_Scores_Sweetness  Data_Scores_Moisture  \
# 0                     10.00                  10.00                  0.12
# 1                     10.00                  10.00                  0.12
# 2                     10.00                  10.00                  0.11
# 3                     10.00                  10.00                  0.11
# 4                     10.00                  10.00                  0.11
# ..                      ...                    ...                   ...
# 577                    9.33                  10.00                  0.10
# 578                    8.67                   9.33                  0.10
# 579                   10.00                  10.00                  0.11
# 580                    8.67                   8.67                  0.10
# 581                    0.00                   0.00                  0.12
#
#      Data_Color Data_Type_Variety
# 0         Green           Bourbon
# 1         Green           Bourbon
# 2    Blue-Green           Bourbon
# 3    Blue-Green           Bourbon
# 4         Green           Bourbon
# ..          ...               ...
# 577       Green           Bourbon
# 578       Green           Bourbon
# 579       Green            Catuai
# 580       Green           Bourbon
# 581       Green           Caturra
#
# [582 rows x 11 columns]

# %%
df_short.isna().sum()
# Out:
# Data_Scores_Aroma          0
# Data_Scores_Flavor         0
# Data_Scores_Aftertaste     0
# Data_Scores_Acidity        0
# Data_Scores_Body           0
# Data_Scores_Balance        0
# Data_Scores_Uniformity     0
# Data_Scores_Sweetness      0
# Data_Scores_Moisture       0
# Data_Color                35
# Data_Type_Variety          0
# dtype: int64

# %%
df_short = df_short.dropna().reset_index(drop=True)
df_short
# Out:
#      Data_Scores_Aroma  Data_Scores_Flavor  Data_Scores_Aftertaste  \
# 0                 8.50                8.50                    8.00
# 1                 8.50                8.17                    8.00
# 2                 8.33                8.00                    8.00
# 3                 8.00                8.00                    8.00
# 4                 8.00                7.92                    7.75
# ..                 ...                 ...                     ...
# 542               7.33                7.25                    6.92
# 543               7.33                7.42                    7.33
# 544               7.58                7.00                    6.75
# 545               7.58                7.67                    7.42
# 546               0.00                0.00                    0.00
#
#      Data_Scores_Acidity  Data_Scores_Body  Data_Scores_Balance  \
# 0                   8.00              8.00                 8.00
# 1                   7.75              8.00                 8.00
# 2                   8.00              7.75                 8.00
# 3                   7.67              7.75                 8.00
# 4                   7.75              8.00                 7.75
# ..                   ...               ...                  ...
# 542                 7.33              7.25                 7.33
# 543                 7.42              7.50                 7.42
# 544                 6.92              7.00                 6.92
# 545                 7.42              7.67                 7.67
# 546                 0.00              0.00                 0.00
#
#      Data_Scores_Uniformity  Data_Scores_Sweetness  Data_Scores_Moisture  \
# 0                     10.00                  10.00                  0.12
# 1                     10.00                  10.00                  0.12
# 2                     10.00                  10.00                  0.11
# 3                     10.00                  10.00                  0.11
# 4                     10.00                  10.00                  0.11
# ..                      ...                    ...                   ...
# 542                    9.33                  10.00                  0.10
# 543                    8.67                   9.33                  0.10
# 544                   10.00                  10.00                  0.11
# 545                    8.67                   8.67                  0.10
# 546                    0.00                   0.00                  0.12
#
#      Data_Color Data_Type_Variety
# 0         Green           Bourbon
# 1         Green           Bourbon
# 2    Blue-Green           Bourbon
# 3    Blue-Green           Bourbon
# 4         Green           Bourbon
# ..          ...               ...
# 542       Green           Bourbon
# 543       Green           Bourbon
# 544       Green            Catuai
# 545       Green           Bourbon
# 546       Green           Caturra
#
# [547 rows x 11 columns]

# %%
df_short.isna().sum()
# Out:
# Data_Scores_Aroma         0
# Data_Scores_Flavor        0
# Data_Scores_Aftertaste    0
# Data_Scores_Acidity       0
# Data_Scores_Body          0
# Data_Scores_Balance       0
# Data_Scores_Uniformity    0
# Data_Scores_Sweetness     0
# Data_Scores_Moisture      0
# Data_Color                0
# Data_Type_Variety         0
# dtype: int64

# %%
print("Rows Dropped:", num_rows - len(df_short))
# Out:
# Rows Dropped: 35

# %% [markdown]
# ### 1.3. Dropping Three Large Outliers
#
# This dataset has three prominent outliers.
# * Two of these outliers are characterized by having dramatically low `Aroma` values that are less than 5.5.
# * One of these outliers is characterized by having a dramatically low `Acidity` value that is less than 5.5.
#
#
# Drop these three outliers.

# %%
df_short = df_short[(df_short['Data_Scores_Aroma'] >= 5.5) & (df_short['Data_Scores_Acidity'] >= 5.5)].reset_index(drop=True)
df_short
# Out:
#      Data_Scores_Aroma  Data_Scores_Flavor  Data_Scores_Aftertaste  \
# 0                 8.50                8.50                    8.00
# 1                 8.50                8.17                    8.00
# 2                 8.33                8.00                    8.00
# 3                 8.00                8.00                    8.00
# 4                 8.00                7.92                    7.75
# ..                 ...                 ...                     ...
# 539               7.33                7.08                    6.92
# 540               7.33                7.25                    6.92
# 541               7.33                7.42                    7.33
# 542               7.58                7.00                    6.75
# 543               7.58                7.67                    7.42
#
#      Data_Scores_Acidity  Data_Scores_Body  Data_Scores_Balance  \
# 0                   8.00              8.00                 8.00
# 1                   7.75              8.00                 8.00
# 2                   8.00              7.75                 8.00
# 3                   7.67              7.75                 8.00
# 4                   7.75              8.00                 7.75
# ..                   ...               ...                  ...
# 539                 7.08              7.42                 7.17
# 540                 7.33              7.25                 7.33
# 541                 7.42              7.50                 7.42
# 542                 6.92              7.00                 6.92
# 543                 7.42              7.67                 7.67
#
#      Data_Scores_Uniformity  Data_Scores_Sweetness  Data_Scores_Moisture  \
# 0                     10.00                  10.00                  0.12
# 1                     10.00                  10.00                  0.12
# 2                     10.00                  10.00                  0.11
# 3                     10.00                  10.00                  0.11
# 4                     10.00                  10.00                  0.11
# ..                      ...                    ...                   ...
# 539                   10.00                  10.00                  0.10
# 540                    9.33                  10.00                  0.10
# 541                    8.67                   9.33                  0.10
# 542                   10.00                  10.00                  0.11
# 543                    8.67                   8.67                  0.10
#
#      Data_Color Data_Type_Variety
# 0         Green           Bourbon
# 1         Green           Bourbon
# 2    Blue-Green           Bourbon
# 3    Blue-Green           Bourbon
# 4         Green           Bourbon
# ..          ...               ...
# 539       Green           Caturra
# 540       Green           Bourbon
# 541       Green           Bourbon
# 542       Green            Catuai
# 543       Green           Bourbon
#
# [544 rows x 11 columns]

# %% [markdown]
# ### 1.4. Implicit Missing Values in the Categorical Variables
#
# 1. Do you have any reason to believe that there are some implicit missing values in the categorical variables that we intend to use?
# 2. If so, drop all rows that have these missing values.

# %%
df_short.dtypes
# Out:
# Data_Scores_Aroma         float64
# Data_Scores_Flavor        float64
# Data_Scores_Aftertaste    float64
# Data_Scores_Acidity       float64
# Data_Scores_Body          float64
# Data_Scores_Balance       float64
# Data_Scores_Uniformity    float64
# Data_Scores_Sweetness     float64
# Data_Scores_Moisture      float64
# Data_Color                 object
# Data_Type_Variety          object
# dtype: object

# %%
df_short['Data_Color'].unique()
# Out:
# array(['Green', 'Blue-Green', 'Bluish-Green', 'Unknown'], dtype=object)

# %%
df_short['Data_Type_Variety'].unique()
# Out:
# array(['Bourbon', 'Catuai', 'Caturra', 'Typica'], dtype=object)

# %%
df_short = df_short[df_short['Data_Color'] != "Unknown"].reset_index(drop=True)
df_short
# Out:
#      Data_Scores_Aroma  Data_Scores_Flavor  Data_Scores_Aftertaste  \
# 0                 8.50                8.50                    8.00
# 1                 8.50                8.17                    8.00
# 2                 8.33                8.00                    8.00
# 3                 8.00                8.00                    8.00
# 4                 8.00                7.92                    7.75
# ..                 ...                 ...                     ...
# 499               7.33                7.08                    6.92
# 500               7.33                7.25                    6.92
# 501               7.33                7.42                    7.33
# 502               7.58                7.00                    6.75
# 503               7.58                7.67                    7.42
#
#      Data_Scores_Acidity  Data_Scores_Body  Data_Scores_Balance  \
# 0                   8.00              8.00                 8.00
# 1                   7.75              8.00                 8.00
# 2                   8.00              7.75                 8.00
# 3                   7.67              7.75                 8.00
# 4                   7.75              8.00                 7.75
# ..                   ...               ...                  ...
# 499                 7.08              7.42                 7.17
# 500                 7.33              7.25                 7.33
# 501                 7.42              7.50                 7.42
# 502                 6.92              7.00                 6.92
# 503                 7.42              7.67                 7.67
#
#      Data_Scores_Uniformity  Data_Scores_Sweetness  Data_Scores_Moisture  \
# 0                     10.00                  10.00                  0.12
# 1                     10.00                  10.00                  0.12
# 2                     10.00                  10.00                  0.11
# 3                     10.00                  10.00                  0.11
# 4                     10.00                  10.00                  0.11
# ..                      ...                    ...                   ...
# 499                   10.00                  10.00                  0.10
# 500                    9.33                  10.00                  0.10
# 501                    8.67                   9.33                  0.10
# 502                   10.00                  10.00                  0.11
# 503                    8.67                   8.67                  0.10
#
#      Data_Color Data_Type_Variety
# 0         Green           Bourbon
# 1         Green           Bourbon
# 2    Blue-Green           Bourbon
# 3    Blue-Green           Bourbon
# 4         Green           Bourbon
# ..          ...               ...
# 499       Green           Caturra
# 500       Green           Bourbon
# 501       Green           Bourbon
# 502       Green            Catuai
# 503       Green           Bourbon
#
# [504 rows x 11 columns]

# %%
print("Rows dropped:", 544 - len(df_short))
# Out:
# Rows dropped: 40

# %% [markdown]
# ## 2. Training and Test Datasets
#
# We intend to build linear regression models that will predict the `Aroma` of *new coffee brands* using some of the following explanatory variables.
#
# * `Flavor`
# * `Aftertaste`
# * `Acidity`
# * `Body`
# * `Balance`
# * `Uniformity`
# * `Sweetness`
# * `Moisture`
# * `Color`
# * `Variety`
#
#
# Using some combination of these explanatory variables, we'd like to build and select a linear regression model which we can infer might perform well when it comes to predicting the `Aroma` of *new coffee brands*. Thus, let's create a training and a test dataset from our cleaned dataframe from 1.4.
#
# Use a random state of `437` to do this. Your training dataset should be 80% of observations from your cleaned dataframe.

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df_short, test_size=0.2, random_state=437)
print(df_train.shape[0] / df_short.shape[0])
df_train.head()
# Out:
# 0.7996031746031746
#      Data_Scores_Aroma  Data_Scores_Flavor  Data_Scores_Aftertaste  \
# 133               7.42                7.00                    7.42
# 109               7.33                7.42                    7.33
# 278               6.50                6.33                    6.50
# 264               7.25                7.08                    7.00
# 223               7.58                7.58                    7.50
#
#      Data_Scores_Acidity  Data_Scores_Body  Data_Scores_Balance  \
# 133                 7.25              7.08                 7.33
# 109                 7.67              7.42                 7.25
# 278                 7.50              7.33                 6.83
# 264                 7.17              7.17                 7.08
# 223                 7.50              7.50                 7.50
#
#      Data_Scores_Uniformity  Data_Scores_Sweetness  Data_Scores_Moisture  \
# 133                   10.00                  10.00                  0.12
# 109                   10.00                  10.00                  0.12
# 278                    8.67                   8.67                  0.11
# 264                   10.00                  10.00                  0.12
# 223                   10.00                  10.00                  0.12
#
#     Data_Color Data_Type_Variety
# 133      Green            Typica
# 109      Green           Caturra
# 278      Green           Bourbon
# 264      Green           Bourbon
# 223      Green            Typica

# %% [markdown]
# ## 3. Pre-Analysis
#
# Before fitting our linear regression models, let's perform the following relevant pre-analyses on the **training dataset**.
#
# ### 3.1. Numerical Variable Relationships
#
# 1. Plot the relationship between all pairs of numerical variables in the training dataset. Use at most two lines of code to do this.
# 2. Also find the correlation between each pair of numerical variables in the training dataset.

# %%
sns.pairplot(df_short)
plt.show()

# %%
numerical_cols = ['Data_Scores_Aroma', 'Data_Scores_Flavor', 'Data_Scores_Aftertaste', 
                  'Data_Scores_Acidity', 'Data_Scores_Body', 'Data_Scores_Balance', 
                  'Data_Scores_Uniformity', 'Data_Scores_Sweetness', 'Data_Scores_Moisture']
correlation_matrix = df_short[numerical_cols].corr()
print(correlation_matrix)
# Out:
#                         Data_Scores_Aroma  Data_Scores_Flavor  \
# Data_Scores_Aroma                1.000000            0.741111
# Data_Scores_Flavor               0.741111            1.000000
# Data_Scores_Aftertaste           0.683578            0.850305
# Data_Scores_Acidity              0.595893            0.737344
# Data_Scores_Body                 0.570248            0.650583
# Data_Scores_Balance              0.677256            0.744886
# Data_Scores_Uniformity           0.220378            0.268765
# Data_Scores_Sweetness            0.141691            0.263747
# Data_Scores_Moisture            -0.110576           -0.137416
#
#                         Data_Scores_Aftertaste  Data_Scores_Acidity  \
# Data_Scores_Aroma                     0.683578             0.595893
# Data_Scores_Flavor                    0.850305             0.737344
# Data_Scores_Aftertaste                1.000000             0.676895
# Data_Scores_Acidity                   0.676895             1.000000
# Data_Scores_Body                      0.686171             0.618541
# Data_Scores_Balance                   0.778266             0.657957
# Data_Scores_Uniformity                0.288407             0.279570
# Data_Scores_Sweetness                 0.261403             0.176894
# Data_Scores_Moisture                 -0.189228            -0.124401
#
#                         Data_Scores_Body  Data_Scores_Balance  \
# Data_Scores_Aroma               0.570248             0.677256
# Data_Scores_Flavor              0.650583             0.744886
# Data_Scores_Aftertaste          0.686171             0.778266
# Data_Scores_Acidity             0.618541             0.657957
# Data_Scores_Body                1.000000             0.681258
# Data_Scores_Balance             0.681258             1.000000
# Data_Scores_Uniformity          0.165331             0.343517
# Data_Scores_Sweetness           0.158820             0.282362
# Data_Scores_Moisture           -0.186067            -0.212098
#
#                         Data_Scores_Uniformity  Data_Scores_Sweetness  \
# Data_Scores_Aroma                     0.220378               0.141691
# Data_Scores_Flavor                    0.268765               0.263747
# Data_Scores_Aftertaste                0.288407               0.261403
# Data_Scores_Acidity                   0.279570               0.176894
# Data_Scores_Body                      0.165331               0.158820
# Data_Scores_Balance                   0.343517               0.282362
# Data_Scores_Uniformity                1.000000               0.482668
# Data_Scores_Sweetness                 0.482668               1.000000
# Data_Scores_Moisture                 -0.026373              -0.002836
#
#                         Data_Scores_Moisture
# Data_Scores_Aroma                  -0.110576
# Data_Scores_Flavor                 -0.137416
# Data_Scores_Aftertaste             -0.189228
# Data_Scores_Acidity                -0.124401
# Data_Scores_Body                   -0.186067
# Data_Scores_Balance                -0.212098
# Data_Scores_Uniformity             -0.026373
# Data_Scores_Sweetness              -0.002836
# Data_Scores_Moisture                1.000000

# %% [markdown]
# ### 3.2. Multicollinearity
#
# If we were to use *all* of the listed numerical explanatory variables in our model to predict `Aroma`, do you think that our linear regression model will have an issue with multicollinearity? Explain.

# %% [markdown]
# Yes our model will have an issue with multicollinearity because we have numerical explanatory variables that have a high correlation with each other. These include Flavor and Aftertaste, Flavor and Acidity, Flavor and Balance, and Aftertaste and Balance.

# %% [markdown]
# ### 3.3. Categorical Explanatory Variable Association with Eachother
#
# Is there an association that exists between our two categorical explanatory variables `Variety` and `Color`? Use and interpret the appropriate visualization to explain.

# %%
temp = pd.crosstab(df_short['Data_Color'], df_short['Data_Type_Variety'], normalize='index')
temp
temp.plot.bar()
plt.legend(loc='upper right')
plt.ylabel("Relative Frequency")
plt.show()

# %% [markdown]
# Yes there is an assocation between Color and Variety as we can see from the graph for e.g. the percentage of Catuai that are Blue-Green is nearly double the Catuai that are Bluish-Green. As all of the bars in the graph with the same colors have different height, it shows that there is an association between the two categorical variables

# %% [markdown]
# ### 3.4. Categorical Explanatory Variable Association with `Aroma`
#
# Which of our two categorical explanatory variables has a stronger association with our response variable `Aroma`? Use and interpret the appropriate visualizations to explain.

# %%
sns.boxplot(x='Data_Color', y='Data_Scores_Aroma', data=df_short)
plt.show()

# %%
sns.boxplot(x='Data_Type_Variety', y='Data_Scores_Aroma', data=df_short)
plt.show()

# %% [markdown]
# Both categorical variables have a weak relationship with our numerical variable aroma as their IQR boxes have a significant overlap. However, Data_Type_Variety has a stronger association with Aroma as compared to Color because Type's median is more separate and the IQR boxes have less overlap as compared to Color.

# %% [markdown]
# ### 3.5. Moisture Distribution
#
# 1. Plot a histogram for the `Moisture` variable.
# 2. What is the modality of this moisture distribution variable?

# %%
df_short['Data_Scores_Moisture'].hist()
plt.title("Coffee Varieties Moisture")
plt.xlabel("Moisture")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# The moisture variable is bimodal as looking at the histogram we can see it has two major peaks. One peak is between 0.00 and 0.015 and another peak is between 0.098 and 0.115.

# %% [markdown]
# ### <u>Tutorial</u>: Creating a Categorical Variable from a Numerical Variable
# If we'd ever like to create a 0/1 categorical variable based on whether or not a given numerical variable in a dataframe meets a certain condition, we can use a code like that which is shown below.

# %%
df_temp = pd.DataFrame({'x':[0,1,2,100,101,102],'y':[1,2,1,2,3,4]})
df_temp
# Out:
#      x  y
# 0    0  1
# 1    1  2
# 2    2  1
# 3  100  2
# 4  101  3
# 5  102  4

# %% [markdown]
# By putting the condition that you're checking in parantheses, this create a pandas series of True/False values, stipulating whether or not the condition is met.

# %%
(df_temp['x']>50)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# Name: x, dtype: bool

# %% [markdown]
# By multiplying this pandas series by 1,
# * True gets converted to a 1
# * False gets converted to a 0
#
# An so for instance, we've created a 0/1 categorical variable that assesses whether or not the `x` column in our dataframe is greater than 50.

# %%
df_temp['high_x'] = 1*(df_temp['x']>50)
df_temp
# Out:
#      x  y  high_x
# 0    0  1       0
# 1    1  2       0
# 2    2  1       0
# 3  100  2       1
# 4  101  3       1
# 5  102  4       1

# %% [markdown]
# ### 3.6. Modality of Moisture
#
# 1. Create a categorical variable that determines whether or not a coffee belongs to the "high moisture mode" or the "low moisture mode".
# 2. Does `Variety` or `Color` have a stronger association with this variable that you just created? Explain.

# %%
high_moisture_mode = 1*(df_short['Data_Scores_Moisture'] >= 0.06)
high_moisture_mode
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 499    1
# 500    1
# 501    1
# 502    1
# 503    1
# Name: Data_Scores_Moisture, Length: 504, dtype: int32

# %%
temp = pd.crosstab(df_short['Data_Color'], high_moisture_mode, normalize='index')
temp.plot.bar()
plt.legend(loc='upper right')
plt.ylabel("Relative Frequency")
plt.show()

# %%
temp = pd.crosstab(df_short['Data_Type_Variety'], high_moisture_mode, normalize='index')
temp.plot.bar()
plt.legend(loc='upper right')
plt.ylabel("Relative Frequency")
plt.show()

# %% [markdown]
# Variety has a stronger association with our high/low moisture categorical variable. This is because the difference in the bars for high moisture and low moisture for each category is more pronounced in variety as compared to color.

# %% [markdown]
# ## 4. Full Model
#
# Next, let's fit our "full model" with our training dataest. This will predict the `Aroma` of coffees using ALL of the following explanatory variables.
#
# * `Flavor`
# * `Aftertaste`
# * `Acidity`
# * `Body`
# * `Balance`
# * `Uniformity`
# * `Sweetness`
# * `Moisture`
# * `Color`
# * `Variety`
#
#
# ### 4.1. Fitting the Model
#
# Fit this model with your training dataset. Display the summary output table for this model.

# %%
full_model = smf.ols(formula='Data_Scores_Aroma~Data_Scores_Flavor+Data_Scores_Aftertaste+Data_Scores_Acidity+Data_Scores_Body+Data_Scores_Balance+Data_Scores_Uniformity+Data_Scores_Moisture+Data_Scores_Sweetness+Data_Color+Data_Type_Variety', data=df_train).fit()
full_model

# %%
full_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Data_Scores_Aroma   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.592
# Method:                 Least Squares   F-statistic:                     45.95
# Date:                Tue, 20 Feb 2024   Prob (F-statistic):           2.45e-70
# Time:                        22:51:56   Log-Likelihood:                 147.11
# No. Observations:                 403   AIC:                            -266.2
# Df Residuals:                     389   BIC:                            -210.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        2.5824      0.316      8.162      0.000       1.960       3.204
# Data_Color[T.Bluish-Green]      -0.0344      0.049     -0.708      0.480      -0.130       0.061
# Data_Color[T.Green]             -0.0737      0.038     -1.942      0.053      -0.148       0.001
# Data_Type_Variety[T.Catuai]     -0.0185      0.030     -0.624      0.533      -0.077       0.040
# Data_Type_Variety[T.Caturra]    -0.0008      0.022     -0.037      0.970      -0.044       0.042
# Data_Type_Variety[T.Typica]     -0.0111      0.027     -0.416      0.678      -0.063       0.041
# Data_Scores_Flavor               0.4034      0.057      7.140      0.000       0.292       0.515
# Data_Scores_Aftertaste           0.0388      0.059      0.658      0.511      -0.077       0.155
# Data_Scores_Acidity              0.0048      0.049      0.098      0.922      -0.091       0.100
# Data_Scores_Body                 0.0522      0.050      1.038      0.300      -0.047       0.151
# Data_Scores_Balance              0.2159      0.048      4.501      0.000       0.122       0.310
# Data_Scores_Uniformity           0.0159      0.021      0.761      0.447      -0.025       0.057
# Data_Scores_Moisture             0.0497      0.244      0.203      0.839      -0.430       0.530
# Data_Scores_Sweetness           -0.0457      0.018     -2.537      0.012      -0.081      -0.010
# ==============================================================================
# Omnibus:                        5.982   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                7.543
# Skew:                          -0.127   Prob(JB):                       0.0230
# Kurtosis:                       3.621   Cond. No.                         827.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 4.2. Aroma Variability
#
# #### 4.2.1. What percent of aroma variability in the training dataset is explained by the model?

# %% [markdown]
# 60.6%

# %% [markdown]
# #### 4.2.2. What percent of aroma variability in the training dataset is NOT explained by the model?

# %%
print("Not explained:", (1-0.606) * 100)
# Out:
# Not explained: 39.4

# %% [markdown]
# ### 4.3. Linearity Assumption
#
# 1. Does this full model meet the linearity assumption? Explain.
# 2. Is a linear regression model (using the full set of explanatory variables to predict `Aroma`) a suitable *type* of model to use for the given training dataset? Explain.

# %%
plt.scatter(full_model.fittedvalues, full_model.resid)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Fitted (Predicted) values')
plt.ylabel('Residuals')
plt.title('Fitted values vs. Residuals Plot')
plt.show()

# %% [markdown]
# Yes our full model meets the linearity condition because, for the most part, each one of the small-width boxes in the fitted values vs residual plot above has a roughly even distribution of positive and negative residual values. There is a linear relationship between the explanatory variables and response variable in this dataset. Thus, a linear regression model is a suitable type of model for this dataset.

# %% [markdown]
# ### 4.4. Model Fit
#
# #### 4.4.1. Training Data R^2
#
# Calculate the R^2 of the training dataset and use it to evaluate the fit of the model on  the training dataset.

# %%
from sklearn.metrics import r2_score

y_train = df_train['Data_Scores_Aroma']
y_pred_train = full_model.predict(df_train)
r2_score(y_train, y_pred_train)
# Out:
# 0.6055958321571462

# %% [markdown]
# The fit of the model is good because it has an acceptable R^2 value of above 0.5

# %% [markdown]
# #### 4.4.2. Test Data R^2
#
# 1. Calculate the R^2 of the test dataset and use it to evaluate the fit of the model on the test dataset.
# 2. Is this model a better fit for the training dataset or the test dataset? Is your answer what you might expect? Explain.

# %%
y_test = df_test['Data_Scores_Aroma']
y_pred_test = full_model.predict(df_test)
r2_score(y_test, y_pred_test)
# Out:
# 0.5680945869314865

# %% [markdown]
# This model is a better fit for the training dataset as the training dataset has a higher R^2 score. This was expected because the training dataset was used to select the best intercepts and slopes for the model. We kept the SSE for the training as low as possible but not for the test hence the slightly lower R^2 score.

# %% [markdown]
# ### 4.5. Multicollinearity
#
# #### 4.5.1. Collinear Variable Pairs
#
# Identify all collinear explanatory variable pairs in the training dataset.
#
# *Use a correlation threshold of 0.7*.

# %%
numerical_cols = ['Data_Scores_Aroma', 'Data_Scores_Flavor', 'Data_Scores_Aftertaste', 
                  'Data_Scores_Acidity', 'Data_Scores_Body', 'Data_Scores_Balance', 
                  'Data_Scores_Uniformity', 'Data_Scores_Sweetness', 'Data_Scores_Moisture']
correlation_matrix = df_train[numerical_cols].corr()
print(correlation_matrix)
# Out:
#                         Data_Scores_Aroma  Data_Scores_Flavor  \
# Data_Scores_Aroma                1.000000            0.739970
# Data_Scores_Flavor               0.739970            1.000000
# Data_Scores_Aftertaste           0.689765            0.850546
# Data_Scores_Acidity              0.581499            0.715437
# Data_Scores_Body                 0.566819            0.628395
# Data_Scores_Balance              0.684277            0.735092
# Data_Scores_Uniformity           0.242375            0.289448
# Data_Scores_Sweetness            0.157478            0.290103
# Data_Scores_Moisture            -0.126252           -0.116162
#
#                         Data_Scores_Aftertaste  Data_Scores_Acidity  \
# Data_Scores_Aroma                     0.689765             0.581499
# Data_Scores_Flavor                    0.850546             0.715437
# Data_Scores_Aftertaste                1.000000             0.670857
# Data_Scores_Acidity                   0.670857             1.000000
# Data_Scores_Body                      0.663520             0.626450
# Data_Scores_Balance                   0.776026             0.642477
# Data_Scores_Uniformity                0.306367             0.292378
# Data_Scores_Sweetness                 0.281569             0.181693
# Data_Scores_Moisture                 -0.180915            -0.100777
#
#                         Data_Scores_Body  Data_Scores_Balance  \
# Data_Scores_Aroma               0.566819             0.684277
# Data_Scores_Flavor              0.628395             0.735092
# Data_Scores_Aftertaste          0.663520             0.776026
# Data_Scores_Acidity             0.626450             0.642477
# Data_Scores_Body                1.000000             0.694580
# Data_Scores_Balance             0.694580             1.000000
# Data_Scores_Uniformity          0.186736             0.350108
# Data_Scores_Sweetness           0.172064             0.291822
# Data_Scores_Moisture           -0.179093            -0.200660
#
#                         Data_Scores_Uniformity  Data_Scores_Sweetness  \
# Data_Scores_Aroma                     0.242375               0.157478
# Data_Scores_Flavor                    0.289448               0.290103
# Data_Scores_Aftertaste                0.306367               0.281569
# Data_Scores_Acidity                   0.292378               0.181693
# Data_Scores_Body                      0.186736               0.172064
# Data_Scores_Balance                   0.350108               0.291822
# Data_Scores_Uniformity                1.000000               0.455631
# Data_Scores_Sweetness                 0.455631               1.000000
# Data_Scores_Moisture                 -0.001274              -0.013677
#
#                         Data_Scores_Moisture
# Data_Scores_Aroma                  -0.126252
# Data_Scores_Flavor                 -0.116162
# Data_Scores_Aftertaste             -0.180915
# Data_Scores_Acidity                -0.100777
# Data_Scores_Body                   -0.179093
# Data_Scores_Balance                -0.200660
# Data_Scores_Uniformity             -0.001274
# Data_Scores_Sweetness              -0.013677
# Data_Scores_Moisture                1.000000

# %% [markdown]
# FLavour and Aftertaste, Flavour and Acidity, Flavour and Balance, Aftertaste and Balance

# %% [markdown]
# #### 4.5.2. Fixing Multicollinearity
#
# Suppose that we are willing to drop at least one (perhaps more) explanatory variables in order to get rid of multicollinearity. What are two distinct candidate models that would get rid of multicollinearity that we could try to fit?

# %% [markdown]
# The two distinct candidate models we can have that would get rid of multicollinearity is that we can have one model that drops flavour and another model that drops aftertaste.

# %% [markdown]
# #### 4.5.3 Potential Downsides of Multicollinearity
#
# Give two *potential* downsides that our full model might experience if our full linear regression model has an issue with multicollinearity.

# %% [markdown]
# We will have misleading slopes so it may not accurately show the relationship between or numerical and response variable. We might have overfitting so we will have worse test dataset performance.

# %% [markdown]
# ## 5. Candidate Model 1
#
#
# ### 5.1. Fitting the Model
# Fit your **candidate model 1** that you selected above. Show the summary output table for this model.

# %%
model1 = smf.ols(formula='Data_Scores_Aroma~Data_Scores_Aftertaste+Data_Scores_Acidity+Data_Scores_Body+Data_Scores_Balance+Data_Scores_Uniformity+Data_Scores_Moisture+Data_Scores_Sweetness+Data_Color+Data_Type_Variety', data=df_train).fit()
model1

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Data_Scores_Aroma   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.540
# Method:                 Least Squares   F-statistic:                     40.35
# Date:                Tue, 20 Feb 2024   Prob (F-statistic):           5.87e-61
# Time:                        23:38:38   Log-Likelihood:                 122.30
# No. Observations:                 403   AIC:                            -218.6
# Df Residuals:                     390   BIC:                            -166.6
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        2.5730      0.336      7.656      0.000       1.912       3.234
# Data_Color[T.Bluish-Green]      -0.0239      0.052     -0.463      0.644      -0.125       0.078
# Data_Color[T.Green]             -0.0662      0.040     -1.644      0.101      -0.145       0.013
# Data_Type_Variety[T.Catuai]     -0.0412      0.031     -1.319      0.188      -0.103       0.020
# Data_Type_Variety[T.Caturra]    -0.0228      0.023     -0.994      0.321      -0.068       0.022
# Data_Type_Variety[T.Typica]     -0.0204      0.028     -0.723      0.470      -0.076       0.035
# Data_Scores_Aftertaste           0.2894      0.050      5.747      0.000       0.190       0.388
# Data_Scores_Acidity              0.1107      0.049      2.249      0.025       0.014       0.208
# Data_Scores_Body                 0.0513      0.053      0.962      0.337      -0.054       0.156
# Data_Scores_Balance              0.2627      0.050      5.205      0.000       0.163       0.362
# Data_Scores_Uniformity           0.0083      0.022      0.373      0.709      -0.035       0.052
# Data_Scores_Moisture             0.1224      0.259      0.472      0.637      -0.387       0.632
# Data_Scores_Sweetness           -0.0338      0.019     -1.771      0.077      -0.071       0.004
# ==============================================================================
# Omnibus:                       12.887   Durbin-Watson:                   1.783
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               24.477
# Skew:                          -0.125   Prob(JB):                     4.84e-06
# Kurtosis:                       4.181   Cond. No.                         777.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 5.2. Test Model R^2
#
# Calculate the test dataset R^2 for this candidate model.

# %%
y_test = df_test['Data_Scores_Aroma']
y_pred_test = model1.predict(df_test)
r2_score(y_test, y_pred_test)
# Out:
# 0.5196298827154263

# %% [markdown]
# ## 6. Candidate Model 2
#
#
# ### 6.1. Fitting the Model
# Fit your **candidate model 2** that you selected above. Show the summary output table for this model.

# %%
model2 = smf.ols(formula='Data_Scores_Aroma~Data_Scores_Flavor+Data_Scores_Acidity+Data_Scores_Body+Data_Scores_Balance+Data_Scores_Uniformity+Data_Scores_Moisture+Data_Scores_Sweetness+Data_Color+Data_Type_Variety', data=df_train).fit()
model2

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Data_Scores_Aroma   R-squared:                       0.605
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     49.81
# Date:                Tue, 20 Feb 2024   Prob (F-statistic):           4.20e-71
# Time:                        23:40:06   Log-Likelihood:                 146.89
# No. Observations:                 403   AIC:                            -267.8
# Df Residuals:                     390   BIC:                            -215.8
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        2.5764      0.316      8.152      0.000       1.955       3.198
# Data_Color[T.Bluish-Green]      -0.0360      0.049     -0.742      0.458      -0.132       0.059
# Data_Color[T.Green]             -0.0754      0.038     -1.993      0.047      -0.150      -0.001
# Data_Type_Variety[T.Catuai]     -0.0158      0.029     -0.539      0.590      -0.073       0.042
# Data_Type_Variety[T.Caturra]     0.0025      0.021      0.118      0.906      -0.039       0.044
# Data_Type_Variety[T.Typica]     -0.0090      0.026     -0.340      0.734      -0.061       0.043
# Data_Scores_Flavor               0.4256      0.045      9.378      0.000       0.336       0.515
# Data_Scores_Acidity              0.0066      0.049      0.136      0.892      -0.089       0.102
# Data_Scores_Body                 0.0572      0.050      1.151      0.250      -0.040       0.155
# Data_Scores_Balance              0.2247      0.046      4.885      0.000       0.134       0.315
# Data_Scores_Uniformity           0.0165      0.021      0.791      0.429      -0.025       0.058
# Data_Scores_Moisture             0.0450      0.244      0.185      0.854      -0.434       0.524
# Data_Scores_Sweetness           -0.0454      0.018     -2.522      0.012      -0.081      -0.010
# ==============================================================================
# Omnibus:                        5.707   Durbin-Watson:                   1.834
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                7.088
# Skew:                          -0.124   Prob(JB):                       0.0289
# Kurtosis:                       3.601   Cond. No.                         779.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 6.2. Test Model R^2
#
# Calculate the test dataset R^2 for this candidate model.

# %%
y_test = df_test['Data_Scores_Aroma']
y_pred_test = model2.predict(df_test)
r2_score(y_test, y_pred_test)
# Out:
# 0.5684843095363926

# %% [markdown]
# ## 7. Evaluating your Models
#
# ### 7.1. Primary Research Goal
#
# Which of your three models that you've built (the full model, candidate model 1, or candidate model 2) best meets your primary research goal (which is to build a predictive model that yields good Aroma predictions for *new coffee brands*)?

# %% [markdown]
# Candidate model 2 would be the best for our primary research goal as it has the highest R^2 score for the test model

# %% [markdown]
# ### 7.2. Secondary Research Goals
#
# Of your three models that you've built (the full model, candidate model 1, or candidate model 2) which would you *trust the least* when it comes to the slopes accurately reflecting the relationship that exists between the variables in the training dataset? Explain.

# %% [markdown]
# I would trust the full model the least as it suffers from multicollinearity as a multicollinear model does not accurately reflect the relationship between the explanatory and response variables.

# %% [markdown]
# ## 8. Final Model
#
# Let's explore the final model that we selected in 7.1 that best meets our primary research goal.
#
# ### 8.1. Linear Regression Equation
#
# Write the linear regression equation for this selected model. Make sure to use appropriate notation.

# %% [markdown]
# Aroma(^) = 2.5764 - (0.0360 x Data_Color[T.Bluish-Green]) - (0.0754 x Data_Color[T.Green]) - (0.0158 x Data_Type_Variety[T.Catuai]) + (0.0025 x Data_Type_Variety[T.Caturra]) - (0.0090 x Data_Type_Variety[T.Typica]) + (0.4256 x Data_Scores_Flavor) + (0.0066 x Data_Scores_Acidity) + (0.0572 x Data_Scores_Body) + (0.2247 x Data_Scores_Balance)+ (0.0165 x Data_Scores_Uniformity) + (0.0450 x Data_Scores_Moisture) - (0.0454 x Data_Scores_Sweetness)

# %% [markdown]
# ### 8.2. Intercept Interpretation
#
# Put the intercept of this model into words. Points will be taken off for using *misleading language*.

# %% [markdown]
# The estimated 'Aroma' score for a coffee variety with not bluish-green color or green color and not catuai variety or caturra variety or typical variety, assuming all other numerical scores are zero.

# %% [markdown]
# ### 8.3. Sweetness Slope Interpretation
#
# Put the sweetness slope of this model into words. Points will be taken off for using *misleading language*.

# %% [markdown]
# The sweetness of this model is -0.0454. For every one unit change in the sweetness score, it affects the aroma by decreasing it by 0.0454.

# %% [markdown]
# ### 8.3. Green Indicator Variable Slope Interpretation
#
# Put the `Green` indicator variable slope of this model into words. Points will be taken off for using *misleading language*.

# %% [markdown]
# The green indicator for the slope is -0.0754. If everything else remains the same, with every one point change in the green indicator slope, the aroma score will decrease by 0.0754.
