# %% [markdown]
# # STAT 207 Lab Assignment 4 - Individual Part - [18 total points] - Solutions
#
# This individual lab will also be atypical in that the number of points is less than 25.

# %% [markdown]
# ## <u>Case Study</u>: Predicting Movie Ratings for *New Datasets*
#
#
#
# ### Movie Rating Dataset Information
#
# In the individual and group assignments we will use the data in the `imdb.csv` to pursue our research goals.
#
# Each row in the `imdb.csv` file contains the following information about **POPULAR** `films` as well as `series` listed on IMDB.
# * `Name`
# * `Date`: the date film/series was released.
# * `Rate`: the rating of the film/series
# * `Votes`: how many votes this film/series received on IMDB
# * `Genre`: a **list** of genres that the film/series is considered to be. Most films/series have multiple genres listed (ex: 'Action, Adventure, Thriller')
# * `Duration`: the duration of the film/series
# * `Type`: whether the row is a `Film` or `Series`
# * `Certificate`: the content rating of the film (ex: 'G', 'PG', 'PG-13', 'R')
# * `Nudity`: the amount of nudity in the film/series
# * `Violence`: the amount of violence in the film/series
# * `Profanity`: the amount of profanity in the film/series
# * `Alcohol`: the amount of alcohol in the film/series
# * `Frightening`: the amount of frightening content in the film/series
#
# (We will *not* merge this `imdb.csv` ratings dataframe with the actors dataframe in the `ReelView.csv` due to how few rows there were left over after the merge that we saw in the group assignment).
#
#
# ### Individual Assignment Research Goal
#
# In this individual assignment we would like to build a linear regression model that will predict `Rate` based on other available explanatory variables in the dataset. Ideally, we would like to be able to effectively *use* the model that we select to predict the `Rate` of *new* Popular IMDB listed movies that come out. So in other words, we would like to build a linear regression model that we can infer has good `Rate` predictions for *new datasets*.
#
# We will fit multiple possible linear regression models and evaluate which of these models might best help us meet our research goal.
#
#
# <p>&nbsp;</p>
# <table style="border: none;border-collapse: collapse;width:102pt;">
#     <tbody>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;width:51pt;">Problem</td>
#             <td style="color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;border-left:none;width:51pt;">Points</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.25</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.25</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.3.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.3.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">6.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">6.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">6.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">7.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">7.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">7.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">8</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#     </tbody>
# </table>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. IMDB Dataset
#
# ### 1.1. Reading the csv
#
# 1. Read the `imdb.csv` into a dataframe. The strings that are used to represent missing values in this csv file are `No Rate`, `No Votes`, and `None`. Make sure that these values are converted to NaN values when you read the csv file.
# 2. Show the first 5 rows.
# 3. Show how many rows this dataframe has.

# %%
df = pd.read_csv("C:\\Users\\samma\\Documents\\stat207\\saraza2\\lab_04\\imdb.csv", na_values=['No Rate', 'No Votes', 'None'])
df.head()
# Out:
#                           Name  Date  Rate     Votes  \
# 0               No Time to Die  2021   7.6  107163.0
# 1                   The Guilty  2021   6.3   64375.0
# 2    The Many Saints of Newark  2021   6.4   27145.0
# 3  Venom: Let There Be Carnage  2021   6.4   30443.0
# 4                         Dune  2021   8.3   84636.0
#
#                          Genre  Duration  Type Certificate    Nudity  \
# 0  Action, Adventure, Thriller     163.0  Film       PG-13      Mild
# 1       Crime, Drama, Thriller      90.0  Film           R       NaN
# 2                 Crime, Drama     120.0  Film           R  Moderate
# 3    Action, Adventure, Sci-Fi      97.0  Film       PG-13       NaN
# 4     Action, Adventure, Drama     155.0  Film       PG-13       NaN
#
#    Violence Profanity   Alcohol Frightening
# 0  Moderate      Mild      Mild    Moderate
# 1       NaN    Severe       NaN    Moderate
# 2    Severe    Severe  Moderate    Moderate
# 3  Moderate  Moderate      Mild    Moderate
# 4  Moderate       NaN      Mild    Moderate

# %%
len(df)
# Out:
# 6178

# %% [markdown]
# ### 1.2. Missing Value Cleaning
#
# 1. First create a dataframe that only contains the columns that we care about for this analysis: `Name`, `Rate`, `Date`, `Votes`,`Certificate`, `Type`, `Genre`, and `Alcohol`.
# 2. Then drop all rows with NaN values from this dataframe.
# 3. How many rows did we drop?

# %%
df_short = df[['Name', 'Rate', 'Date', 'Votes', 'Certificate', 'Type', 'Genre', 'Alcohol']]
df_short.isna().sum()
# Out:
# Name              0
# Rate            185
# Date              0
# Votes           185
# Certificate     450
# Type              0
# Genre             0
# Alcohol        1583
# dtype: int64

# %%
df_short = df_short.dropna()
df_short
# Out:
#                                         Name  Rate  Date     Votes  \
# 0                             No Time to Die   7.6  2021  107163.0
# 2                  The Many Saints of Newark   6.4  2021   27145.0
# 3                Venom: Let There Be Carnage   6.4  2021   30443.0
# 4                                       Dune   8.3  2021   84636.0
# 5                                  Ted Lasso   8.8  2021  117562.0
# ...                                      ...   ...   ...       ...
# 6173  The Human Centipede II (Full Sequence)   3.8  2011   37492.0
# 6174                        Double Indemnity   8.3  1944  150448.0
# 6175      Before the Devil Knows You're Dead   7.3  2007  100668.0
# 6176                              Queen Bees   6.0  2021     887.0
# 6177                              Death Race   6.3  2008  203578.0
#
#      Certificate    Type                        Genre   Alcohol
# 0          PG-13    Film  Action, Adventure, Thriller      Mild
# 2              R    Film                 Crime, Drama  Moderate
# 3          PG-13    Film    Action, Adventure, Sci-Fi      Mild
# 4          PG-13    Film     Action, Adventure, Drama      Mild
# 5          TV-MA  Series         Comedy, Drama, Sport      Mild
# ...          ...     ...                          ...       ...
# 6173   Not Rated    Film                       Horror      Mild
# 6174      Passed    Film      Crime, Drama, Film-Noir      Mild
# 6175           R    Film       Crime, Drama, Thriller    Severe
# 6176       PG-13    Film       Comedy, Drama, Romance  Moderate
# 6177           R    Film     Action, Sci-Fi, Thriller      Mild
#
# [4595 rows x 8 columns]

# %%
rows_dropped = len(df) - len(df_short)
rows_dropped
# Out:
# 1583

# %% [markdown]
# ### 1.3. Dropping Duplicate Name Rows

# %% [markdown]
# #### 1.3.1. List of Non-Duplicated Movie Names
#
# As we saw in the group assignment, there are rows in this dataframe that have the same movie name. To make things easier for our analysis, let's create a list of all movie `Names` in this dataframe that have ONLY ONE ROW in the dataset that corresponds to it.

# %%
names_count = {}
Names = []
duplicated_names = df_short['Name'].to_list()
for name in duplicated_names:
    if name in names_count:
        val = names_count[name]
        val = val + 1
        names_count[name] = val
    else:
        names_count[name] = 1
for name, count in names_count.items():
    if count == 1:
        Names.append(name)
Names
# Out:
# ['No Time to Die',
#  'The Many Saints of Newark',
#  'Venom: Let There Be Carnage',
#  'Ted Lasso',
#  'What If...?',
#  'Sex Education',
#  'The Walking Dead',
#  'The Sopranos',
#  'Only Murders in the Building',
#  'American Horror Story',
#  'Seinfeld',
#  "Grey's Anatomy",
#  'Game of Thrones',
#  'Black Widow',
#  'The Last Duel',
#  'Alice in Borderland',
#  'Shang-Chi and the Legend of the Ten Rings',
#  'Billions',
#  'Spectre',
#  'Lucifer',
#  'The Morning Show',
#  'Halloween Kills',
#  "There's Someone Inside Your House",
#  'La casa de papel',
#  'The Night House',
#  'Succession',
#  'La Brea',
#  'Skyfall',
#  'NCIS: Naval Criminal Investigative Service',
#  'Big Sky',
#  'Peaky Blinders',
#  'Titane',
#  'American Crime Story',
#  'Stranger Things',
#  'Titans',
#  'Goliath',
#  'Breaking Bad',
#  'On My Block',
#  'The Rookie',
#  'Law & Order: Special Victims Unit',
#  'Hocus Pocus',
#  'Chicago Fire',
#  'You',
#  'Quantum of Solace',
#  'Doom Patrol',
#  'Yellowstone',
#  'The Suicide Squad',
#  'Friends',
#  'Brooklyn Nine-Nine',
#  'Cruella',
#  'The Blacklist',
#  'Supernatural',
#  'Criminal Minds',
#  'Vigil',
#  'Infinite',
#  'The Good Doctor',
#  'Dexter',
#  'The Green Knight',
#  'The French Dispatch',
#  'The Boys',
#  'Vikings',
#  'Silent Witness',
#  'The Card Counter',
#  'Lamb',
#  'Midsomer Murders',
#  'Rick and Morty',
#  'After We Fell',
#  'Riverdale',
#  'The Harder They Fall',
#  'Chicago Med',
#  'Promising Young Woman',
#  'Modern Family',
#  'The Big Bang Theory',
#  'The Wire',
#  'The White Lotus',
#  'The Witcher',
#  'The Starling',
#  'Kate',
#  'Knives Out',
#  'New Amsterdam',
#  'Cry Macho',
#  'Castle',
#  'Black Mirror',
#  'Law & Order: Organized Crime',
#  'Till Death',
#  'The Voyeurs',
#  'The Crown',
#  'Better Call Saul',
#  'Lost',
#  'The Simpsons',
#  'Dear Evan Hansen',
#  'CSI: Crime Scene Investigation',
#  "It's Always Sunny in Philadelphia",
#  'Superstore',
#  'The Resident',
#  'Gisaengchung',
#  'Mr. Robot',
#  'Last Night in Soho',
#  'Titanic',
#  'Ozark',
#  'F9',
#  'Shingeki no kyojin',
#  '365 dni',
#  'Archer',
#  'How I Met Your Mother',
#  'Young Sheldon',
#  '9/1/2001',
#  'Heat',
#  'Chicago P.D.',
#  'The Expanse',
#  'Ghosts',
#  'Fear the Walking Dead',
#  'Bridgerton',
#  'House M.D.',
#  'Good Girls',
#  'The Flash',
#  'Suits',
#  'Once Upon a Time... in Hollywood',
#  'Jungle Cruise',
#  'Gilmore Girls',
#  'True Detective',
#  'Bones',
#  'American Horror Stories',
#  'Intrusion',
#  'Leverage: Redemption',
#  'Blade Runner 2049',
#  'The X Files',
#  "Schitt's Creek",
#  'The Vampire Diaries',
#  'Grantchester',
#  'Blue Bayou',
#  'The Matrix',
#  'ER',
#  'The Wolf of Wall Street',
#  'The Last Kingdom',
#  'The Shawshank Redemption',
#  'Star Trek: The Next Generation',
#  'The Walking Dead: World Beyond',
#  'FBI',
#  'Joker',
#  'Curb Your Enthusiasm',
#  'Boruto: Naruto Next Generations',
#  'Zodiac',
#  'Supergirl',
#  'Snake Eyes: G.I. Joe Origins',
#  'Brassic',
#  'Sons of Anarchy',
#  'Midsommar',
#  'Spencer',
#  'Chapelwaite',
#  'Dave Chappelle: The Closer',
#  'Avengers: Endgame',
#  'Blue Bloods',
#  'Wrath of Man',
#  'Community',
#  'The Duff',
#  'Family Guy',
#  'Tenet',
#  'New Girl',
#  'FBI: International',
#  'Killing Eve',
#  'Dark',
#  'Hotel Transylvania: Transformania',
#  'Pretty Smart',
#  'Stargirl',
#  'This Is Us',
#  'Kota Factory',
#  'The 100',
#  'GoldenEye',
#  'The Godfather',
#  'Rocketman',
#  'Chucky',
#  'Sex/Life',
#  'Beetle Juice',
#  'Magnum P.I.',
#  'Friendzone',
#  'The Rocky Horror Picture Show',
#  'Pig',
#  'The Orville',
#  'Endeavour',
#  'Batoru rowaiaru',
#  'Homeland',
#  'Knock Knock',
#  'The Dark Knight',
#  'Two and a Half Men',
#  'The Protégé',
#  'Parks and Recreation',
#  'Star Trek: Lower Decks',
#  'One Piece: Wan pîsu',
#  'Cobra Kai',
#  'FBI: Most Wanted',
#  "Don't Breathe 2",
#  "Zack Snyder's Justice League",
#  'A Million Little Things',
#  'Reservation Dogs',
#  'Mad Men',
#  'The Goldbergs',
#  'Nobody',
#  'The Tomorrow War',
#  '1917',
#  'Sweet Home',
#  'Station 19',
#  'Law & Order',
#  'The Hunger Games',
#  "Jennifer's Body",
#  'Prison Break',
#  'Outer Banks',
#  'The Power of the Dog',
#  'Sherlock',
#  "Trick 'r Treat",
#  'Prisoners',
#  'Hereditary',
#  'Black as Night',
#  'The Good Girl',
#  'Dr. Death',
#  'It',
#  'The Father',
#  'Die Another Day',
#  'Call the Midwife',
#  'Inception',
#  'Doctor Sleep',
#  'Pulp Fiction',
#  'Ask 101',
#  'The Departed',
#  'Euphoria',
#  'The Umbrella Academy',
#  'Once Upon a Time',
#  'Reminiscence',
#  'Heartland',
#  'Scary Movie',
#  'South Park',
#  'Locke & Key',
#  'The Sinner',
#  'Fight Club',
#  'Rakka',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Mean Girls',
#  'The Shining',
#  'Star Trek: Deep Space Nine',
#  'Dr. No',
#  'Hawaii Five-0',
#  'Arrow',
#  'Léon',
#  'Bosch',
#  'Legends of Tomorrow',
#  'Bingo Hell',
#  'Django Unchained',
#  'Gone Girl',
#  "Bob's Burgers",
#  'Virgin River',
#  "If I Can't Have Love, I Want Power",
#  'SEAL Team',
#  'Love & Other Drugs',
#  'Saturday Night Live',
#  'Scrubs',
#  'Line of Duty',
#  'Gunpowder Milkshake',
#  'Agents of S.H.I.E.L.D.',
#  'The Good Place',
#  'True Blood',
#  'Shadow and Bone',
#  'How to Get Away with Murder',
#  'Mad Max: Fury Road',
#  'Mindhunter',
#  'Man on Fire',
#  'Tusk',
#  'The World Is Not Enough',
#  'Invincible',
#  'Star Trek: Voyager',
#  "On Her Majesty's Secret Service",
#  'Grown Ups',
#  'Fear Street: 1994',
#  'Goodfellas',
#  'Mom',
#  'Inglourious Basterds',
#  'CODA',
#  'The Goonies',
#  'Murder, She Wrote',
#  'The Fifth Element',
#  'The L Word: Generation Q',
#  'Once Upon a Time in America',
#  'Wentworth',
#  '30 Rock',
#  'BoJack Horseman',
#  'The Lighthouse',
#  'Psych',
#  'NCIS: Los Angeles',
#  'The Wonder Years',
#  'Columbo',
#  'The Courier',
#  'Stargate SG-1',
#  'One Tree Hill',
#  'Ghost Ship',
#  'The Marvelous Mrs. Maisel',
#  'Forrest Gump',
#  'Addams Family Values',
#  'Blindspot',
#  "He's All That",
#  'Kingsman: The Secret Service',
#  'Oldeuboi',
#  'Live and Let Die',
#  'Corpse Bride',
#  'Gotham',
#  'Catch Me If You Can',
#  'Frasier',
#  'Deadpool',
#  'The Eyes of Tammy Faye',
#  'Hacks',
#  'American Night',
#  'Bull',
#  'Orange Is the New Black',
#  'Superman and Lois',
#  'Death in Paradise',
#  'Suicide Squad',
#  'Fringe',
#  'American Psycho',
#  'Boss Level',
#  'Bohemian Rhapsody',
#  'La Venganza de las Juanas',
#  "La vie d'Adèle",
#  '24',
#  'Casper',
#  'Vera',
#  'Gaetmaeul Chachacha',
#  'The Conjuring: The Devil Made Me Do It',
#  'Arrested Development',
#  'Boardwalk Empire',
#  'Spartacus: Blood and Sand',
#  'A Clockwork Orange',
#  'Modern Love',
#  'For All Mankind',
#  'Zombieland: Double Tap',
#  'Hubie Halloween',
#  'After',
#  "Hitman's Wife's Bodyguard",
#  'Narcos',
#  'Back to the Future',
#  'Young Frankenstein',
#  'Élite',
#  'Halloween III: Season of the Witch',
#  'Justified',
#  'Wind River',
#  'Wu-Tang: An American Saga',
#  'The School of Rock',
#  'Final Space',
#  'Hellraiser',
#  'Hall Pass',
#  'D.P.',
#  'House of Cards',
#  'Guardians of the Galaxy',
#  'Stillwater',
#  'Alien',
#  'Se7en',
#  'Thor: Ragnarok',
#  'Space Jam: A New Legacy',
#  'Tomorrow Never Dies',
#  'Druk',
#  'Captain Marvel',
#  'Godzilla vs. Kong',
#  "Gerald's Game",
#  'Jurassic Park',
#  "That '70s Show",
#  'Something Borrowed',
#  'The Leftovers',
#  'The Mentalist',
#  'Naruto: Shippûden',
#  'No Country for Old Men',
#  'Goldfinger',
#  'The Other Two',
#  'Blade Runner',
#  'The Killing',
#  'Smallville',
#  'Jack Ryan',
#  'The Forever Purge',
#  'John Wick',
#  'Gunsmoke',
#  'The Girl with the Dragon Tattoo',
#  "She's All That",
#  'Jaws',
#  'Lupin',
#  'Little House on the Prairie',
#  'The Gentlemen',
#  'Halloween 4: The Return of Michael Myers',
#  "Schindler's List",
#  'The Matrix Reloaded',
#  'Legacies',
#  'The Blue Lagoon',
#  '9-1-1: Lone Star',
#  'Little Shop of Horrors',
#  'The Holiday',
#  'Cats',
#  'Murdoch Mysteries',
#  'Mr. Corman',
#  'The Dark Knight Rises',
#  'The Little Things',
#  'The Evil Dead',
#  'The Originals',
#  'Desperate Housewives',
#  'Army of the Dead',
#  "A Knight's Tale",
#  'Why Women Kill',
#  'Fifty Shades of Grey',
#  'Big Little Lies',
#  'Poirot',
#  'Glee',
#  'Edward Scissorhands',
#  'The Internship',
#  'Anna',
#  'The Birds',
#  'Call Me by Your Name',
#  'Get Out',
#  'Spider-Man 3',
#  'The Craft',
#  'White Collar',
#  'Die Hard',
#  'Birds of Paradise',
#  'A Discovery of Witches',
#  "Don't Breathe",
#  "We're the Millers",
#  'Saving Private Ryan',
#  'The Grand Budapest Hotel',
#  'Letterkenny',
#  'The King',
#  'Ready or Not',
#  'Green Lantern',
#  'Nomadland',
#  'Barry Lyndon',
#  'Retfærdighedens ryttere',
#  'The Hangover',
#  'The Amazing Spider-Man',
#  'Final Destination',
#  'The West Wing',
#  'Donnie Darko',
#  'Person of Interest',
#  'Leverage',
#  'The O.C.',
#  'His Dark Materials',
#  'Married with Children',
#  'The Good Wife',
#  'Licence to Kill',
#  'Grave',
#  'Harry Potter and the Goblet of Fire',
#  'Freaky',
#  'Grace and Frankie',
#  'Madres',
#  'Shutter Island',
#  'Avatar',
#  'The Flight Attendant',
#  'Super Mario Bros.',
#  'Elementary',
#  'Star Trek: Picard',
#  'Scream 2',
#  'A.P. Bio',
#  'Into the Night',
#  'In the Dark',
#  'The Hunt',
#  'Tomb Raider',
#  'The Prestige',
#  'Orphan',
#  'Jumper',
#  'Banshee',
#  'Atypical',
#  'Us',
#  'Sicario',
#  'Dynasty',
#  'Whiplash',
#  'Boogie Nights',
#  'Deadpool 2',
#  'Copshop',
#  'It Chapter Two',
#  'Another Life',
#  'Taboo',
#  'Star Wars: The Clone Wars',
#  'Miracle Workers',
#  'Pride & Prejudice',
#  'Most Dangerous Game',
#  '13 Reasons Why',
#  'News of the World',
#  'The Great Gatsby',
#  'The Green Mile',
#  'The Texas Chain Saw Massacre',
#  'Fleabag',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Battlestar Galactica',
#  'Pretty Little Liars',
#  'Man of Steel',
#  'Live by Night',
#  'In Time',
#  'The Social Network',
#  'Hamilton',
#  'Raised by Wolves',
#  'Queen of the South',
#  'Power Book III: Raising Kanan',
#  'Halloween H20: 20 Years Later',
#  'The Big Short',
#  'Prometheus',
#  'Project X',
#  'The Sixth Sense',
#  'From Russia with Love',
#  'Never Have I Ever',
#  'The Good Fight',
#  'Dear White People',
#  'Roswell, New Mexico',
#  'Pose',
#  "Dawson's Creek",
#  'Nocturnal Animals',
#  'The Man in the High Castle',
#  'Mars Attacks!',
#  'The Devil All the Time',
#  'Sen to Chihiro no kamikakushi',
#  'Practical Magic',
#  'Cheers',
#  'Chilling Adventures of Sabrina',
#  'The Lost Boys',
#  'The Cabin in the Woods',
#  'Troy',
#  'Saved by the Bell',
#  'Taxi Driver',
#  'Spiral: From the Book of Saw',
#  'Tokyo Revengers',
#  'Motherland: Fort Salem',
#  'Nightcrawler',
#  'Malcolm in the Middle',
#  'After We Collided',
#  'Black Swan',
#  'Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn',
#  'The Greatest Showman',
#  'Scarface',
#  'Requiem for a Dream',
#  'Tacoma FD',
#  'All American',
#  'The Americans',
#  '3%',
#  'Unforgotten',
#  'The Haunted Mansion',
#  'American Beauty',
#  'Mumbai Diaries 26/11',
#  'Ex Machina',
#  'Last Man Standing',
#  'Narcos: México',
#  'Love, Death & Robots',
#  "Mythic Quest: Raven's Banquet",
#  'Saw',
#  'Good Will Hunting',
#  'Halloween: Resurrection',
#  'Hacksaw Ridge',
#  'The Revenant',
#  'Fear Street: 1978',
#  'The Nevers',
#  'The Conners',
#  'Logan',
#  'Jojo Rabbit',
#  'Dazed and Confused',
#  'The Chair',
#  'One Hour Photo',
#  'Walker',
#  'Top Gun',
#  'Idi i smotri',
#  'Six Feet Under',
#  'Men in Black',
#  'The Lord of the Rings: The Return of the King',
#  'Britannia',
#  'Small Engine Repair',
#  'Star Wars',
#  'The Stand',
#  'Death Note: Desu nôto',
#  'Clueless',
#  'Baby Driver',
#  'The Ice Road',
#  'Harry Potter and the Prisoner of Azkaban',
#  'The Outsiders',
#  'Scott Pilgrim vs. the World',
#  'The Mauritanian',
#  'American Pie',
#  'Halloween 5: The Revenge of Michael Myers',
#  '12 Angry Men',
#  'Death Proof',
#  'Atonement',
#  'Longmire',
#  'NCIS: New Orleans',
#  'Naruto',
#  'Moonrise Kingdom',
#  'Clue',
#  'El hoyo',
#  'In the Heights',
#  'Altered Carbon',
#  'Deadwood',
#  'No Sudden Move',
#  'The Neighborhood',
#  'Barry',
#  'The Irishman',
#  'Step Brothers',
#  'BAC Nord',
#  'Broadchurch',
#  'Dunkirk',
#  'Firefly',
#  'Aquaman',
#  'Cashback',
#  'The Living Daylights',
#  '28 Days Later...',
#  'The King of Queens',
#  'American Dad!',
#  'Night Hunter',
#  'Love and Monsters',
#  'The Bold Type',
#  'Avengers: Age of Ultron',
#  'Silicon Valley',
#  'There Will Be Blood',
#  'Beverly Hills, 90210',
#  'Designated Survivor',
#  'Oz',
#  'A Nightmare on Elm Street 3: Dream Warriors',
#  'iZombie',
#  'Iron Man',
#  'Hunter x Hunter',
#  'Private Practice',
#  'Thor',
#  'The Lobster',
#  'Transformers',
#  'Batwoman',
#  'Ray Donovan',
#  'Sense8',
#  'The Boy in the Striped Pyjamas',
#  'Annette',
#  'Training Day',
#  'Raiders of the Lost Ark',
#  'CSI: Miami',
#  'Pearl Harbor',
#  'Matilda',
#  'The Amazing Spider-Man 2',
#  'Love Life',
#  'Coco',
#  'Desperado',
#  'Judas and the Black Messiah',
#  'Grimm',
#  'Gomorra: La serie',
#  'Alita: Battle Angel',
#  'The Godfather: Part II',
#  'Pitch Perfect',
#  'Prodigal Son',
#  'The Dreamers',
#  'Babylon 5',
#  'American Gods',
#  'Futurama',
#  'The Dry',
#  'Eternal Sunshine of the Spotless Mind',
#  'Spider-Man 2',
#  'The Martian',
#  'StartUp',
#  'Scream 4',
#  'Jumanji',
#  'The Guest',
#  'Ah-ga-ssi',
#  'Watchmen',
#  'Aliens',
#  'Mother!',
#  'John Wick: Chapter 3 - Parabellum',
#  'Green Book',
#  'Tommy Boy',
#  'Kill Bill: Vol. 1',
#  'It Follows',
#  'Gemini Man',
#  'Chuck',
#  'Vacation Friends',
#  'Snatch',
#  'Black Sails',
#  'Il buono, il brutto, il cattivo',
#  'The Notebook',
#  'Castlevania',
#  'The Hobbit: An Unexpected Journey',
#  'Split',
#  'Ginny & Georgia',
#  'Slasher',
#  'The Descent',
#  'The Usual Suspects',
#  'Edge of Tomorrow',
#  'Reign',
#  'Emily in Paris',
#  'Nancy Drew',
#  'Godfather of Harlem',
#  'Jolt',
#  'Layer Cake',
#  'Stardust',
#  'Tom & Jerry',
#  'Srpski film',
#  'The Matrix Revolutions',
#  'The Kominsky Method',
#  'Power',
#  "One Flew Over the Cuckoo's Nest",
#  'Nanatsu no taizai',
#  'Drive',
#  'Batman Begins',
#  'Resident Alien',
#  'E.T. the Extra-Terrestrial',
#  'The End of the F***ing World',
#  'Sinister',
#  'The Nanny',
#  'The Lovely Bones',
#  'Into the Wild',
#  'The Newsroom',
#  'The Ring',
#  'Brokeback Mountain',
#  'The Cave',
#  'The Big Lebowski',
#  'Rome',
#  'Adult Material',
#  'Mulholland Dr.',
#  'Uncut Gems',
#  "Miss Peregrine's Home for Peculiar Children",
#  'Hidden Figures',
#  'Cloud Atlas',
#  'Carnival Row',
#  'Alias',
#  'Monster House',
#  'The Outsider',
#  'Bron/Broen',
#  'Crimson Peak',
#  'Trainspotting',
#  'Black Hawk Down',
#  'Freedom Writers',
#  'Extraction',
#  'Host',
#  'Elvira: Mistress of the Dark',
#  'The Andy Griffith Show',
#  'The Blues Brothers',
#  'Apocalypse Now',
#  'Almost Famous',
#  'The Great',
#  'V for Vendetta',
#  'Guardians of the Galaxy Vol. 2',
#  'Ang-ma-reul bo-at-da',
#  'Palm Springs',
#  'The Mask',
#  'Ford v Ferrari',
#  'Braveheart',
#  'From Dusk Till Dawn',
#  'Veep',
#  'Memento',
#  'Kingsman: The Golden Circle',
#  'The Way Way Back',
#  'Jack Reacher',
#  'The Hateful Eight',
#  'Respect',
#  'The Babysitter',
#  'Fantastic Mr. Fox',
#  'Pretty Woman',
#  'The IT Crowd',
#  "Pan's Labyrinth",
#  'Anne',
#  'Mr. & Mrs. Smith',
#  'Queen of the Damned',
#  'Upload',
#  'Halloween: The Curse of Michael Myers',
#  'Luther',
#  'The Witcher: Nightmare of the Wolf',
#  'Jane the Virgin',
#  'Black Clover',
#  'Enemy',
#  'Departure',
#  'Me Before You',
#  'Way Down',
#  'Level 16',
#  'Robin Hood: Prince of Thieves',
#  'Kaubôi bibappu',
#  'Logan Lucky',
#  'American History X',
#  'Grease',
#  'Dead to Me',
#  'Yesterday',
#  'Girls',
#  'Jurassic World',
#  'Knight and Day',
#  'The Town',
#  'Bridesmaids',
#  'Road House',
#  'Thunderball',
#  'A View to a Kill',
#  'The Accountant',
#  'Mayans M.C.',
#  'Demonic',
#  'Justice League',
#  'Cold Case',
#  'The Righteous Gemstones',
#  'Les Misérables',
#  'Irréversible',
#  'Will & Grace',
#  'Home Alone',
#  'Malèna',
#  'Good Boys',
#  'Scandal',
#  'The Truman Show',
#  'Never Say Never Again',
#  'Happy Endings',
#  'Burn Notice',
#  'Harry Potter and the Deathly Hallows: Part 1',
#  'Children of the Corn',
#  'After Life',
#  'The Deuce',
#  'Possession',
#  'Servant',
#  'Basic Instinct',
#  'Wild Wild West',
#  'Independence Day',
#  'Extracurricular',
#  'Good Omens',
#  '3rd Rock from the Sun',
#  'Younger',
#  'Jumanji: Welcome to the Jungle',
#  'Shadowplay',
#  'The Texas Chainsaw Massacre',
#  'Lewis',
#  'Merlin',
#  'The Woman in the Window',
#  'X-Men',
#  'Signs',
#  'Scooby-Doo',
#  'Sin City',
#  'Fury',
#  'Hagane no renkinjutsushi',
#  "A Nightmare on Elm Street Part 2: Freddy's Revenge",
#  'Batman v Superman: Dawn of Justice',
#  'The Lord of the Rings: The Two Towers',
#  'JoJo no kimyô-na bôken',
#  'Oblivion',
#  'The League',
#  'Q-Force',
#  "That '80s Show",
#  'The Tudors',
#  'Skins',
#  'The Spy Who Loved Me',
#  'Jagten',
#  'Grown Ups 2',
#  'The Conjuring 2',
#  'Tombstone',
#  'Mr Inbetween',
#  'Fantastic Beasts: The Crimes of Grindelwald',
#  'Super 8',
#  'Love Actually',
#  "Agatha Christie's Marple",
#  "Willy's Wonderland",
#  'The Faculty',
#  'The Pianist',
#  'Salinui chueok',
#  'Harry Potter and the Half-Blood Prince',
#  "Kim's Convenience",
#  'Heroes',
#  'Q',
#  "The Devil's Advocate",
#  'Jessica Jones',
#  'Cruel Intentions',
#  'The Hunger Games: Catching Fire',
#  'Veronica Mars',
#  'Bates Motel',
#  'Binsenjo',
#  'Crazy Rich Asians',
#  'Reservoir Dogs',
#  'I Care a Lot',
#  'Zombieland',
#  'The Empty Man',
#  'V/H/S',
#  'Motherless Brooklyn',
#  'Her',
#  'Captain America: Civil War',
#  'Everybody Loves Raymond',
#  'Pirates of the Caribbean: Dead Men Tell No Tales',
#  'The Closer',
#  '6 Underground',
#  'Secretary',
#  'An American Werewolf in London',
#  'Jurassic World: Fallen Kingdom',
#  'Legend',
#  'Werewolves Within',
#  "National Lampoon's Animal House",
#  'Lady Bird',
#  'Alien: Covenant',
#  'Sa-rang-eui bul-sa-chak',
#  'Diamonds Are Forever',
#  'The Strangers',
#  'Annihilation',
#  'Mr. Mercedes',
#  'Safe House',
#  'Harley Quinn',
#  'Romeo + Juliet',
#  'Terminator 2: Judgment Day',
#  'The Affair',
#  'Dead Poets Society',
#  'Gremlins',
#  'Doctor Who',
#  'Idiocracy',
#  'Red Sparrow',
#  'Doc Martin',
#  'Casino',
#  'Flight',
#  'Office Space',
#  'Cruel Summer',
#  'Darkest Hour',
#  'Lovecraft Country',
#  'Salò o le 120 giornate di Sodoma',
#  'Interview with the Vampire: The Vampire Chronicles',
#  'Law & Order: Criminal Intent',
#  'The Last Letter from Your Lover',
#  'The Intouchables',
#  'The Magicians',
#  'The Fog',
#  'Body of Lies',
#  'Boy Meets World',
#  'Cidade de Deus',
#  'Unfaithful',
#  'X-Men Origins: Wolverine',
#  'Gangs of London',
#  'The Fresh Prince of Bel-Air',
#  'The Fast and the Furious: Tokyo Drift',
#  'Ant-Man',
#  'Your Honor',
#  'Minari',
#  'The Strain',
#  'Final Destination 2',
#  'Three Billboards Outside Ebbing, Missouri',
#  'Now You See Me',
#  'American Hustle',
#  'The Reader',
#  'Captain Fantastic',
#  'A Beautiful Mind',
#  '10 Things I Hate About You',
#  'The Witches of Eastwick',
#  'Fantastic Beasts and Where to Find Them',
#  'About Time',
#  'Fate: The Winx Saga',
#  'Hit and Run',
#  "Ferris Bueller's Day Off",
#  'When Calls the Heart',
#  'Big Mouth',
#  'Travelers',
#  'Californication',
#  'Scream Queens',
#  'Lara Croft: Tomb Raider',
#  'Full Metal Jacket',
#  'Ratched',
#  'RED',
#  'The Game',
#  'The New Mutants',
#  'Fast & Furious Presents: Hobbs & Shaw',
#  'Ouija: Origin of Evil',
#  'Shazam!',
#  'Road to Perdition',
#  'Home Again',
#  'The Human Centipede (First Sequence)',
#  'Batman & Robin',
#  'You Only Live Twice',
#  'The Shield',
#  'The Breakfast Club',
#  'Aftermath',
#  'Predator',
#  'Father Brown',
#  'True Romance',
#  'Southpaw',
#  'Reba',
#  'The Imitation Game',
#  'Armageddon',
#  'Starship Troopers',
#  'Freddy vs. Jason',
#  'Mrs. Doubtfire',
#  'Happy Gilmore',
#  'Poldark',
#  'Blood & Water',
#  'Big Trouble in Little China',
#  'The Blind Side',
#  'King Richard',
#  'The Terminal',
#  'The Graduate',
#  'Octopussy',
#  'Stand by Me',
#  'The Mother',
#  'Midnight in Paris',
#  'The Terminator',
#  'The Fast and the Furious',
#  'King of the Hill',
#  'Not Another Teen Movie',
#  "Clarkson's Farm",
#  'Star Wars: Episode VIII - The Last Jedi',
#  'The Killing of a Sacred Deer',
#  'Lucy',
#  'Derry Girls',
#  'Blood Red Sky',
#  'You Belong to Me',
#  'American Gangster',
#  'Dark Phoenix',
#  'The Shape of Water',
#  'Survivor',
#  'The Hunt for Red October',
#  'The Monster Squad',
#  'The Mindy Project',
#  "L.A.'s Finest",
#  'Unforgiven',
#  'The Marksman',
#  'Fighting with My Family',
#  'Penny Dreadful',
#  'Run',
#  'World War Z',
#  'Underworld',
#  ...]

# %% [markdown]
# #### 1.3.2. Dropping Movies with Duplicate Names
#
# Finally, use this `Name` list from 1.3.1 to drop all rows that correspond to a `Name` that had more than one row assigned to it. (Or in other words drop the movies that we considered "duplicates").
#
# How many additional rows did you drop?

# %%
def process(row):
    current_name = row['Name']
    if current_name in Names:
        return True
    else:
        return False
df_short['Name Exists'] = df_short.apply(process, axis=1)
df_short
# Out:
#                                         Name  Rate  Date     Votes  \
# 0                             No Time to Die   7.6  2021  107163.0
# 2                  The Many Saints of Newark   6.4  2021   27145.0
# 3                Venom: Let There Be Carnage   6.4  2021   30443.0
# 4                                       Dune   8.3  2021   84636.0
# 5                                  Ted Lasso   8.8  2021  117562.0
# ...                                      ...   ...   ...       ...
# 6173  The Human Centipede II (Full Sequence)   3.8  2011   37492.0
# 6174                        Double Indemnity   8.3  1944  150448.0
# 6175      Before the Devil Knows You're Dead   7.3  2007  100668.0
# 6176                              Queen Bees   6.0  2021     887.0
# 6177                              Death Race   6.3  2008  203578.0
#
#      Certificate    Type                        Genre   Alcohol  Name Exists
# 0          PG-13    Film  Action, Adventure, Thriller      Mild         True
# 2              R    Film                 Crime, Drama  Moderate         True
# 3          PG-13    Film    Action, Adventure, Sci-Fi      Mild         True
# 4          PG-13    Film     Action, Adventure, Drama      Mild        False
# 5          TV-MA  Series         Comedy, Drama, Sport      Mild         True
# ...          ...     ...                          ...       ...          ...
# 6173   Not Rated    Film                       Horror      Mild        False
# 6174      Passed    Film      Crime, Drama, Film-Noir      Mild        False
# 6175           R    Film       Crime, Drama, Thriller    Severe        False
# 6176       PG-13    Film       Comedy, Drama, Romance  Moderate        False
# 6177           R    Film     Action, Sci-Fi, Thriller      Mild        False
#
# [4595 rows x 9 columns]

# %%
filtered_df = df_short[df_short['Name Exists'] != False]
filtered_df = filtered_df.drop('Name Exists', axis=1).reset_index()
filtered_df
# Out:
#       index                         Name  Rate  Date     Votes Certificate  \
# 0         0               No Time to Die   7.6  2021  107163.0       PG-13
# 1         2    The Many Saints of Newark   6.4  2021   27145.0           R
# 2         3  Venom: Let There Be Carnage   6.4  2021   30443.0       PG-13
# 3         5                    Ted Lasso   8.8  2021  117562.0       TV-MA
# 4         8                  What If...?   7.6  2021   51959.0       TV-14
# ...     ...                          ...   ...   ...       ...         ...
# 2714   3872                  The Burning   6.4  1981   17549.0           R
# 2715   3873                   Sinister 2   5.3  2015   51685.0           R
# 2716   3874          Weekend at Bernie's   6.4  1989   52730.0       PG-13
# 2717   3876                          Mud   7.4  2012  174443.0       PG-13
# 2718   3877                  La pianiste   7.5  2001   60093.0           R
#
#         Type                         Genre   Alcohol
# 0       Film   Action, Adventure, Thriller      Mild
# 1       Film                  Crime, Drama  Moderate
# 2       Film     Action, Adventure, Sci-Fi      Mild
# 3     Series          Comedy, Drama, Sport      Mild
# 4     Series  Animation, Action, Adventure      Mild
# ...      ...                           ...       ...
# 2714    Film                        Horror      Mild
# 2715    Film     Horror, Mystery, Thriller      Mild
# 2716    Film      Adventure, Comedy, Crime      Mild
# 2717    Film                         Drama      Mild
# 2718    Film                  Drama, Music      Mild
#
# [2719 rows x 9 columns]

# %%
dropped_rows = len(df_short) - len(filtered_df)
dropped_rows
# Out:
# 1876

# %% [markdown]
# ### 1.4. Keeping the Most Common Certificates
#
# Finally, let's keep only the movies that correspond to the most "well known" content ratings: 'R', 'PG-13', 'PG', 'G'.

# %%
df_certificates = filtered_df[(filtered_df.Certificate == "R") | (filtered_df.Certificate == "PG-13") | (filtered_df.Certificate == "PG") | (filtered_df.Certificate == "G")]
df_certificates = df_certificates.drop('index', axis=1)
df_certificates
# Out:
#                              Name  Rate  Date     Votes Certificate  Type  \
# 0                  No Time to Die   7.6  2021  107163.0       PG-13  Film
# 1       The Many Saints of Newark   6.4  2021   27145.0           R  Film
# 2     Venom: Let There Be Carnage   6.4  2021   30443.0       PG-13  Film
# 13                    Black Widow   6.8  2021  246603.0       PG-13  Film
# 14                  The Last Duel   7.7  2021    6498.0           R  Film
# ...                           ...   ...   ...       ...         ...   ...
# 2714                  The Burning   6.4  1981   17549.0           R  Film
# 2715                   Sinister 2   5.3  2015   51685.0           R  Film
# 2716          Weekend at Bernie's   6.4  1989   52730.0       PG-13  Film
# 2717                          Mud   7.4  2012  174443.0       PG-13  Film
# 2718                  La pianiste   7.5  2001   60093.0           R  Film
#
#                             Genre   Alcohol
# 0     Action, Adventure, Thriller      Mild
# 1                    Crime, Drama  Moderate
# 2       Action, Adventure, Sci-Fi      Mild
# 13      Action, Adventure, Sci-Fi      Mild
# 14         Action, Drama, History      Mild
# ...                           ...       ...
# 2714                       Horror      Mild
# 2715    Horror, Mystery, Thriller      Mild
# 2716     Adventure, Comedy, Crime      Mild
# 2717                        Drama      Mild
# 2718                 Drama, Music      Mild
#
# [1746 rows x 8 columns]

# %% [markdown]
# ## 2. Pre-Analysis: Movie Names with the Highest Ratings for Each Year
#
# Before fitting our linear regression model, let's perform one more pre-analysis. We'd specifically like to find the name(s) of the movies that have the **worst** `Rate`ing for each `Date` (ie. year) in the dataset.
#
# #2.1 and #2.2 break this down into two steps for you.
#
# ### 2.1. Dataframe with Highest Ratings
#
# First, create a dataframe that shows the **lowest** `Rate` a movie received in each `Date` (ie. year) in the dataframe. Your final dataframe should be comprised of just two columns:
# * `Date`
# * `Rate`
#
# And your index should be the typical 0,1,2,...

# %%
df_temp = df_certificates[['Date', 'Rate']]
df_low = df_temp.groupby("Date").agg("min").reset_index()
df_low
# Out:
#     Date  Rate
# 0   1941   8.3
# 1   1942   8.5
# 2   1946   8.6
# 3   1954   7.0
# 4   1955   7.7
# ..   ...   ...
# 64  2018   4.5
# 65  2019   2.7
# 66  2020   4.7
# 67  2021   2.5
# 68  2022   6.9
#
# [69 rows x 2 columns]

# %% [markdown]
# ### 2.2. Getting the Names of the Movies
#
# Next, perform an **inner join merge** of this dataframe from 2.1 and your dataframe from 1.4 on the `Rate` and `Date` columns in both dataframes.

# %%
df_merge = pd.merge(df_low, df_certificates, how='inner', left_on=['Date', 'Rate'], right_on=['Date', 'Rate'])
df_merge
# Out:
#     Date  Rate                               Name     Votes Certificate  Type  \
# 0   1941   8.3                       Citizen Kane  423573.0          PG  Film
# 1   1942   8.5                         Casablanca  544369.0          PG  Film
# 2   1946   8.6              It's a Wonderful Life  423418.0          PG  Film
# 3   1954   7.0     Creature from the Black Lagoon   28594.0           G  Film
# 4   1955   7.7              Rebel Without a Cause   87109.0       PG-13  Film
# ..   ...   ...                                ...       ...         ...   ...
# 65  2019   2.7                               Cats   46903.0          PG  Film
# 66  2020   4.7                             Capone   18869.0           R  Film
# 67  2020   4.7                           Songbird    8455.0       PG-13  Film
# 68  2021   2.5                         Cosmic Sin   10329.0           R  Film
# 69  2022   6.9  Hotel Transylvania: Transformania     316.0          PG  Film
#
#                            Genre   Alcohol
# 0                 Drama, Mystery      Mild
# 1            Drama, Romance, War      Mild
# 2         Drama, Family, Fantasy      Mild
# 3                 Horror, Sci-Fi      Mild
# 4                          Drama      Mild
# ..                           ...       ...
# 65         Comedy, Drama, Family      Mild
# 66       Biography, Crime, Drama  Moderate
# 67       Drama, Sci-Fi, Thriller      Mild
# 68     Action, Adventure, Sci-Fi      Mild
# 69  Animation, Adventure, Comedy    Severe
#
# [70 rows x 8 columns]

# %% [markdown]
# ### 2.3. Why More Rows?
#
# Why do you think your dataframe from 2.2 has more rows than your dataframe in 2.1?

# %% [markdown]
# The dataframe from 2.2 has one more row because there are two movies from 2020 which have the same lowest rating of 4.7. In the dataframe from 2.1, we only had to show the minimum rating hence it only showed 4.7 for 2020 which meant one less row.

# %% [markdown]
# ## 3. Additional Explanatory Variable
#
# Let's create another explanatory variable to use in some of our linear regression models.
#
# ### 3.1. Creating is_drama Variable
#
# Create a new variable in your dataframe from 1.4 that indicates whether or not `Drama` is one of the genres listed in the `Genre` column. If 'Drama' is included, your variable should say 'yes'. If not, it should say 'no'.

# %%
def checkDrama(x):
    if "drama" in x.lower():
        return "yes"
    else:
        return "no"

df_certificates['Is_Drama'] = df_certificates['Genre'].apply(checkDrama)
df_certificates
# Out:
#                              Name  Rate  Date     Votes Certificate  Type  \
# 0                  No Time to Die   7.6  2021  107163.0       PG-13  Film
# 1       The Many Saints of Newark   6.4  2021   27145.0           R  Film
# 2     Venom: Let There Be Carnage   6.4  2021   30443.0       PG-13  Film
# 13                    Black Widow   6.8  2021  246603.0       PG-13  Film
# 14                  The Last Duel   7.7  2021    6498.0           R  Film
# ...                           ...   ...   ...       ...         ...   ...
# 2714                  The Burning   6.4  1981   17549.0           R  Film
# 2715                   Sinister 2   5.3  2015   51685.0           R  Film
# 2716          Weekend at Bernie's   6.4  1989   52730.0       PG-13  Film
# 2717                          Mud   7.4  2012  174443.0       PG-13  Film
# 2718                  La pianiste   7.5  2001   60093.0           R  Film
#
#                             Genre   Alcohol Is_Drama
# 0     Action, Adventure, Thriller      Mild       no
# 1                    Crime, Drama  Moderate      yes
# 2       Action, Adventure, Sci-Fi      Mild       no
# 13      Action, Adventure, Sci-Fi      Mild       no
# 14         Action, Drama, History      Mild      yes
# ...                           ...       ...      ...
# 2714                       Horror      Mild       no
# 2715    Horror, Mystery, Thriller      Mild       no
# 2716     Adventure, Comedy, Crime      Mild       no
# 2717                        Drama      Mild      yes
# 2718                 Drama, Music      Mild      yes
#
# [1746 rows x 9 columns]

# %% [markdown]
# ### 3.2. Association with Rating
#
# Is there a STRONG association between the `Rate` variable and the `is_drama` variable in this dataset? Use the appropriate visualization to determine this and explain your answer.

# %%
sns.boxplot(x='Is_Drama', y='Rate', data=df_certificates)
plt.show()

# %% [markdown]
# There is a partial overlap between the IQR boxes of the two variables which suggests that there is an association between the two variables but not necessarily a strong association

# %% [markdown]
# ## 4. Train-Test-Split
#
# Randomly split your cleaned dataframe from 1.4 into a training dataframe and a test dataframe. Your training dataframe should be comprised of 85% of the rows and your test dataframe should be comprised of 15% of the rows. **Use a random_state of 207**.

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df_certificates, test_size=0.15, random_state=207)
print(df_train.shape[0] / df_certificates.shape[0])
df_train.head()
# Out:
# 0.849942726231386
#                        Name  Rate  Date     Votes Certificate  Type  \
# 603       Love and Monsters   7.0  2020  109343.0       PG-13  Film
# 2340         50 First Dates   6.8  2004  339671.0       PG-13  Film
# 1275               Rocky IV   6.9  1985  195262.0          PG  Film
# 130              Blue Bayou   7.1  2021    1833.0           R  Film
# 1270  House of 1000 Corpses   6.1  2003   82053.0           R  Film
#
#                           Genre Alcohol Is_Drama
# 603   Action, Adventure, Comedy    Mild       no
# 2340     Comedy, Drama, Romance    Mild      yes
# 1275               Drama, Sport    Mild      yes
# 130                       Drama    Mild      yes
# 1270                     Horror    Mild       no

# %% [markdown]
# ## 5. Training and Testing Model 1
#
# ### 5.1. Fitting the Linear Regression Model with the Training Dataset
#
# First, fit a multiple linear regression model with your **training dataset** that predicts `Rate` with the following four explanatory variables:
# * `Date`
# * `Votes`
# * `Certificate`
# * `Alcohol`
#
# Show your summary output table for this model.

# %%
import statsmodels.formula.api as smf
slr_model = smf.ols(formula='Rate~Date+Votes+Certificate+Alcohol', data=df_train).fit()
slr_model

# %%
slr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Rate   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.360
# Method:                 Least Squares   F-statistic:                     120.1
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):          1.27e-139
# Time:                        20:14:37   Log-Likelihood:                -1632.7
# No. Observations:                1484   AIC:                             3281.
# Df Residuals:                    1476   BIC:                             3324.
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               34.0706      3.015     11.300      0.000      28.157      39.985
# Certificate[T.PG]       -0.1269      0.205     -0.619      0.536      -0.529       0.275
# Certificate[T.PG-13]    -0.2830      0.205     -1.380      0.168      -0.685       0.119
# Certificate[T.R]        -0.0824      0.203     -0.405      0.685      -0.481       0.316
# Alcohol[T.Moderate]      0.0094      0.051      0.185      0.853      -0.090       0.109
# Alcohol[T.Severe]        0.0780      0.090      0.869      0.385      -0.098       0.254
# Date                    -0.0137      0.002     -9.004      0.000      -0.017      -0.011
# Votes                 1.895e-06    7.2e-08     26.335      0.000    1.75e-06    2.04e-06
# ==============================================================================
# Omnibus:                      201.586   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              375.245
# Skew:                          -0.850   Prob(JB):                     3.29e-82
# Kurtosis:                       4.783   Cond. No.                     5.64e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.64e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### 5.2. Writing out the linear regression model
#
# Write out the linear regression model equation that was fitted in 5.1. Make sure to use the appropriate notation that was discussed in class.

# %% [markdown]
# Rate(^) = 34.0706 - (0.1269 x Certificate[T.PG]) - (0.2830 x Certificate[T.PG-13]) - (0.0824 x Certificate[T.R]) + (0.0094 x Alcohol[T.Moderate]) + (0.0780 x Alcohol[T.Severe]) - (0.0137 x Date) + (1.895e-06 x Votes)

# %% [markdown]
# ### 5.3. Test Dataset RMSE
#
# Now, calculate the test dataset RMSE of this model 1.

# %%
from sklearn.metrics import root_mean_squared_error

y_test = df_test['Rate']

y_pred_test = slr_model.predict(df_test)
rmse_test = root_mean_squared_error(y_test, y_pred_test)
rmse_test
# Out:
# 0.7027524866236846

# %% [markdown]
# ## 6. Training and Testing Model 2
#
# ### 6.1. Fitting the Linear Regression Model with the Training Dataset
#
# Now, fit another multiple linear regression model with your **training dataset** that predicts `Rate` with the following five explanatory variables:
# * `Date`
# * `Votes`
# * `Certificate`
# * `Alcohol`
# * `is_drama`
#
# Show your summary output table for this model.

# %%
full_model = smf.ols(formula='Rate~Date+Votes+Certificate+Alcohol+Is_Drama', data=df_train).fit()
full_model

# %%
full_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Rate   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     157.5
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):          1.02e-191
# Time:                        20:35:37   Log-Likelihood:                -1508.8
# No. Observations:                1484   AIC:                             3036.
# Df Residuals:                    1475   BIC:                             3083.
# Df Model:                           8
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               36.6783      2.779     13.198      0.000      31.227      42.130
# Certificate[T.PG]       -0.0384      0.189     -0.203      0.839      -0.409       0.332
# Certificate[T.PG-13]    -0.2125      0.189     -1.126      0.260      -0.583       0.158
# Certificate[T.R]        -0.0922      0.187     -0.493      0.622      -0.459       0.275
# Alcohol[T.Moderate]     -0.0205      0.047     -0.438      0.661      -0.112       0.071
# Alcohol[T.Severe]        0.0157      0.083      0.189      0.850      -0.147       0.178
# Is_Drama[T.yes]          0.5816      0.036     16.369      0.000       0.512       0.651
# Date                    -0.0152      0.001    -10.794      0.000      -0.018      -0.012
# Votes                 1.868e-06   6.63e-08     28.201      0.000    1.74e-06       2e-06
# ==============================================================================
# Omnibus:                      324.553   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              871.274
# Skew:                          -1.139   Prob(JB):                    6.39e-190
# Kurtosis:                       5.984   Cond. No.                     5.65e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.65e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### 6.2. Writing out the linear regression model
#
# Write out the linear regression model that was fitted in 5.1. Make sure to use the appropriate notation that was discussed in class.

# %% [markdown]
# Rate(^) = 36.6783 - (0.0384 x Certificate[T.PG]) - (0.2125 x Certificate[T.PG-13]) - (0.0922 x Certificate[T.R]) - (0.0205 x Alcohol[T.Moderate]) + (0.0157 x Alcohol[T.Severe]) + (0.5816 x Is_Drama[T.yes]) - (0.0152 x Date) + (1.868e-06 x Votes)

# %% [markdown]
# ### 6.3. Test Dataset RMSE
#
# Now, calculate the test dataset RMSE of this model 2.

# %%
y_test = df_test['Rate']

y_pred_test = full_model.predict(df_test)
rmse_test_full = root_mean_squared_error(y_test, y_pred_test)
rmse_test_full
# Out:
# 0.6510031589760036

# %% [markdown]
# ## 7. Evaluating Models
#
# ### 7.1. Which Model is Better for the Research Goal
#
# Does this analysis suggest that model 1 or model 2 will be better at predicting the rating of *new movies*? Explain.

# %% [markdown]
# Model 2 is better for predicting the rating of new movies because it has a lower RMSE (0.6510031589760036) compared to the RMSE (0.7027524866236846) of model 1

# %% [markdown]
# ### 7.2. Evaluate of the RMSE
#
# Calculate the median `Rate` value of the **test dataset** and compare this to the **test RMSE** of the model that you selected in 7.1.
#
# Evaluate how "good" this test RMSE value is. Explain.

# %%
Ratio = rmse_test_full / df_test['Rate'].median()
Ratio
# Out:
# 0.09300045128228622

# %% [markdown]
# This test RMSE is very good as it has a very low ratio (almost 0) which indicates that the fit of the model is good

# %% [markdown]
# ### 7.3. Rating Prediction
#
# Use your model 2 to predict the rating of a movie that is **rated R**, is **not an drama film**, was released in **2015**, has **90,000 votes**, and has **'Mild' amount of Alcohol**. Calculate this prediction "by hand" (ie. don't use a function.)

# %%
prediction = 36.6783 - (0.0384 * 0) - (0.2125 * 0) - (0.0922 * 1) - (0.0205 * 0) + (0.0157 * 0) + (0.5816 * 0) - (0.0152 * 2015) + (1.868e-06 * 90000)
prediction
# Out:
# 6.126220000000002

# %% [markdown]
# ## 8. Checking Wednesday Practice Round
#
# Create a short <10 second video recording yourself in Zoom using the following steps.
#
# 1. Open up your Illinois Zoom client.
# 2. Record your video using the <u>Record to Cloud</u> option.
#     * <img src="zoom_cloud.png" alt="Description of the image" width=400>
#     * Make sure your mic is on. Your recording should have sound.
#     * Make sure your camera is on.
#     * Make sure that you share your full screen.
#
# 3. Once your're done recording, log off the Zoom client.
# 4. You can find the corresponding recording link here: https://illinois.zoom.us/recording
# 5. Copy-paste the recording link for this video below. IMPORTANT NOTE: When you first create this video, it's possible that this video will still be compiling. This is ok. If you share the link while the video is still compiling, you and anyone else who has the link will be able to see the compiled video once it's ready.
# <img src="compiling.png" alt="Description of the image" width=500>

# %% [markdown]
# https://illinois.zoom.us/rec/share/OfeeAkcbZV5RpGKMIKhvquF2fxKLRQ1D9vjFGig1HGp_FL-oMOs-9GUOTETdKTjd.yPXCUvjLIRQG1PpT?startTime=1707535600000
