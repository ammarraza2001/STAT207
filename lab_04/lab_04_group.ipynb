# %% [markdown]
# # STAT 207 Lab Assignment 4 - Group Part - [12 total points] - Solutions
#
# This group lab will also be atypical in that the number of points is larger than the typical 5.

# %% [markdown]
# ## <u>Case Study</u>: Comparing Movie Ratings based on Famous Actors
#
#
#
# ### Movie Rating Dataset Information
#
# In the individual and group assignments we will use the data in the `imdb.csv` to pursue our research goals.
#
# Each row in the `imdb.csv` file contains the following information about **POPULAR** `films` as well as `series` listed on IMDB.
# * `Name`
# * `Date`: the date film/series was released.
# * `Rate`: the rating of the film/series
# * `Votes`: how many votes this film/series received on IMDB
# * `Genre`: a **list** of genres that the film/series is considered to be. Most films/series have multiple genres listed (ex: 'Action, Adventure, Thriller')
# * `Duration`: the duration of the film/series
# * `Type`: whether the row is a `Film` or `Series`
# * `Certificate`: the content rating of the film (ex: 'G', 'PG', 'PG-13', 'R')
# * `Nudity`: the amount of nudity in the film/series
# * `Violence`: the amount of violence in the film/series
# * `Profanity`: the amount of profanity in the film/series
# * `Alcohol`: the amount of alcohol in the film/series
# * `Frightening`: the amount of frightening content in the film/series
#
# ### Movie Actors Dataset Information
#
# In addition, in the group assignments we will use the data in the `ReelView.csv` to pursue our research goals.
# Each row in the `ReelView.csv` file contains the following additional information about `films` as well as `series` listed on the ReelView website.
#
# * `title`
# * `release_date`
# * `director`: the director of the film/series
# * `cast`: the list of actors in the film/series
#
#
#
#
# ### Group Assignment Goal
#
# In this group assignment you will pick two famous actors and compare the distribution of ratings for films that these actors each apppear in.
#
# <p>&nbsp;</p>
# <table style="border: none;border-collapse: collapse;width:102pt;">
#     <tbody>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;width:51pt;">Problem</td>
#             <td style="color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;border-left:none;width:51pt;">Points</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.5</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.6</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.7</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.5</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#     </tbody>
# </table>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. IMDB Dataset
#
# ### 1.1. Reading the csv
#
# 1. Read the `imdb.csv` into a dataframe. The strings that are used to represent missing values in this csv file are `No Rate`, `No Votes`, and `None`. Make sure that these values are converted to NaN values when you read the csv file.
# 2. Show the first 5 rows.
# 3. Show how many rows this dataframe has.

# %%
na_values = ['No Rate', 'No Votes', 'None']
df = pd.read_csv("C:\\Users\\samma\\Documents\\stat207\\saraza2\\lab_04\\imdb.csv", na_values=na_values)
df.head()
# Out:
#                           Name  Date  Rate     Votes  \
# 0               No Time to Die  2021   7.6  107163.0
# 1                   The Guilty  2021   6.3   64375.0
# 2    The Many Saints of Newark  2021   6.4   27145.0
# 3  Venom: Let There Be Carnage  2021   6.4   30443.0
# 4                         Dune  2021   8.3   84636.0
#
#                          Genre  Duration  Type Certificate    Nudity  \
# 0  Action, Adventure, Thriller     163.0  Film       PG-13      Mild
# 1       Crime, Drama, Thriller      90.0  Film           R       NaN
# 2                 Crime, Drama     120.0  Film           R  Moderate
# 3    Action, Adventure, Sci-Fi      97.0  Film       PG-13       NaN
# 4     Action, Adventure, Drama     155.0  Film       PG-13       NaN
#
#    Violence Profanity   Alcohol Frightening
# 0  Moderate      Mild      Mild    Moderate
# 1       NaN    Severe       NaN    Moderate
# 2    Severe    Severe  Moderate    Moderate
# 3  Moderate  Moderate      Mild    Moderate
# 4  Moderate       NaN      Mild    Moderate

# %%
df_row_count = df.shape[0]
df_row_count
# Out:
# 6178

# %% [markdown]
# ### 1.2. Missing Value Cleaning
#
# 1. First create a dataframe that only contains the the columns that we care about for this pre-analsys: `Name`, `Rate`, `Date`, and `Type`.
# 2. Then drop all rows with NaN values from this dataframe.
# 3. How many rows did we drop?

# %%
df_short = df[['Name', 'Rate', 'Date', 'Type']]
df_short
# Out:
#                                         Name  Rate  Date  Type
# 0                             No Time to Die   7.6  2021  Film
# 1                                 The Guilty   6.3  2021  Film
# 2                  The Many Saints of Newark   6.4  2021  Film
# 3                Venom: Let There Be Carnage   6.4  2021  Film
# 4                                       Dune   8.3  2021  Film
# ...                                      ...   ...   ...   ...
# 6173  The Human Centipede II (Full Sequence)   3.8  2011  Film
# 6174                        Double Indemnity   8.3  1944  Film
# 6175      Before the Devil Knows You're Dead   7.3  2007  Film
# 6176                              Queen Bees   6.0  2021  Film
# 6177                              Death Race   6.3  2008  Film
#
# [6178 rows x 4 columns]

# %%
df_short = df_short.dropna()
df_short
# Out:
#                                         Name  Rate  Date  Type
# 0                             No Time to Die   7.6  2021  Film
# 1                                 The Guilty   6.3  2021  Film
# 2                  The Many Saints of Newark   6.4  2021  Film
# 3                Venom: Let There Be Carnage   6.4  2021  Film
# 4                                       Dune   8.3  2021  Film
# ...                                      ...   ...   ...   ...
# 6173  The Human Centipede II (Full Sequence)   3.8  2011  Film
# 6174                        Double Indemnity   8.3  1944  Film
# 6175      Before the Devil Knows You're Dead   7.3  2007  Film
# 6176                              Queen Bees   6.0  2021  Film
# 6177                              Death Race   6.3  2008  Film
#
# [5993 rows x 4 columns]

# %%
rows_dropped = df_row_count - df_short.shape[0]
rows_dropped
# Out:
# 185

# %% [markdown]
# ### 1.3. Looking for Duplicate Names
#
# #### 1.3.1. Duplicate Example
#
# Create a dataframe that is only comprised of rows with the Name 'Twin Peaks'.

# %%
df_twin_peaks = df_short[df_short.Name == "Twin Peaks"]
df_twin_peaks
# Out:
#             Name  Rate  Date    Type
# 605   Twin Peaks   8.8  2017  Series
# 1380  Twin Peaks   8.5  2017  Series

# %% [markdown]
# #### 1.3.2. List of Non-Duplicated Movie Names
#
# Unfortunately, what you'll see in 1.3.1 is that there are multiple 'Twin Peaks' series with the same `Name` (and Date for that matter), but a different set of other values.
#
# It's possible that this series is a **duplicate** and/orrepresents some sort of "entry error" on the part of whoever compiled this dataset. Unfortunately, duplicate or "entry error" rows in a dataframe can complicate our analyses.
#
# To make things easier for our analysis, let's create a list of all movie `Names` in this dataframe that have ONLY ONE ROW in the dataset that corresponds to it.

# %%
names_count = {}
Names = []
duplicated_names = df_short['Name'].to_list()
for name in duplicated_names:
    if name in names_count:
        val = names_count[name]
        val = val + 1
        names_count[name] = val
    else:
        names_count[name] = 1
for name, count in names_count.items():
    if count == 1:
        Names.append(name)
Names
# Out:
# ['No Time to Die',
#  'The Many Saints of Newark',
#  'Venom: Let There Be Carnage',
#  'Ted Lasso',
#  'Free Guy',
#  'What If...?',
#  'Sex Education',
#  'The Walking Dead',
#  'The Chestnut Man',
#  'Foundation',
#  'The Sopranos',
#  'Only Murders in the Building',
#  'American Horror Story',
#  'Seinfeld',
#  "Grey's Anatomy",
#  'Game of Thrones',
#  'Black Widow',
#  'The Last Duel',
#  'Alice in Borderland',
#  'Shang-Chi and the Legend of the Ten Rings',
#  'Billions',
#  'Spectre',
#  'Lucifer',
#  'The Morning Show',
#  'Halloween Kills',
#  "There's Someone Inside Your House",
#  'Malignant',
#  'La casa de papel',
#  'The Night House',
#  'Succession',
#  'La Brea',
#  'Skyfall',
#  'NCIS: Naval Criminal Investigative Service',
#  'See',
#  'The Addams Family 2',
#  'Big Sky',
#  'Peaky Blinders',
#  'Titane',
#  'American Crime Story',
#  'CSI: Vegas',
#  'Stranger Things',
#  'Titans',
#  'Goliath',
#  'Breaking Bad',
#  'On My Block',
#  'Old',
#  'Y: The Last Man',
#  'The Rookie',
#  'No One Gets Out Alive',
#  'Law & Order: Special Victims Unit',
#  'Hocus Pocus',
#  'Chicago Fire',
#  'You',
#  'Den skyldige',
#  'Quantum of Solace',
#  'Doom Patrol',
#  'Yellowstone',
#  'The Suicide Squad',
#  'Friends',
#  'Brooklyn Nine-Nine',
#  'Cruella',
#  'The Blacklist',
#  'Supernatural',
#  'Criminal Minds',
#  'Vigil',
#  'Infinite',
#  'V/H/S/94',
#  'The Good Doctor',
#  'Dexter',
#  'The Green Knight',
#  'The French Dispatch',
#  'The Boys',
#  'Ridley Road',
#  'Vikings',
#  'Silent Witness',
#  'The Card Counter',
#  'Lamb',
#  'Midsomer Murders',
#  'Rick and Morty',
#  'After We Fell',
#  'Riverdale',
#  'The Harder They Fall',
#  'Chicago Med',
#  'The Lost Symbol',
#  'Star Wars: Visions',
#  'Promising Young Woman',
#  'Modern Family',
#  'The Mandalorian',
#  'Queenpins',
#  'The Big Bang Theory',
#  'The Wire',
#  'The White Lotus',
#  'The Witcher',
#  'The Starling',
#  'Kate',
#  'Knives Out',
#  'New Amsterdam',
#  'Cry Macho',
#  'Castle',
#  'Black Mirror',
#  'Law & Order: Organized Crime',
#  'Till Death',
#  'The Voyeurs',
#  'The Crown',
#  'Better Call Saul',
#  'Lost',
#  'The Simpsons',
#  'Dear Evan Hansen',
#  'CSI: Crime Scene Investigation',
#  'Loki',
#  "It's Always Sunny in Philadelphia",
#  'Superstore',
#  'The Resident',
#  'Gisaengchung',
#  'Mr. Robot',
#  'Last Night in Soho',
#  'Titanic',
#  'Shiddat',
#  'Ozark',
#  'Rise of the Footsoldier: Origins',
#  'F9',
#  'Shingeki no kyojin',
#  '365 dni',
#  'Archer',
#  'How I Met Your Mother',
#  'Chehre',
#  'Young Sheldon',
#  'Black Mafia Family',
#  'Manifest',
#  '9/1/2001',
#  'Heat',
#  'Old Henry',
#  'Chicago P.D.',
#  'The Expanse',
#  'Muppets Haunted Mansion',
#  'American Rust',
#  'Fear the Walking Dead',
#  'Bridgerton',
#  'House M.D.',
#  'Good Girls',
#  'The Flash',
#  'Suits',
#  'Once Upon a Time... in Hollywood',
#  'My Little Pony: A New Generation',
#  'Jungle Cruise',
#  'Gilmore Girls',
#  'True Detective',
#  'Bones',
#  'American Horror Stories',
#  'Intrusion',
#  'Leverage: Redemption',
#  'Blade Runner 2049',
#  'The X Files',
#  'Ordinary Joe',
#  "Schitt's Creek",
#  'The Vampire Diaries',
#  'Grantchester',
#  'Blue Bayou',
#  'The Matrix',
#  'ER',
#  'One of Us Is Lying',
#  'The Wolf of Wall Street',
#  'The Last Kingdom',
#  'The Shawshank Redemption',
#  'Star Trek: The Next Generation',
#  'The Walking Dead: World Beyond',
#  'FBI',
#  'Joker',
#  "Harry Potter and the Sorcerer's Stone",
#  'Curb Your Enthusiasm',
#  'Boruto: Naruto Next Generations',
#  'Zodiac',
#  'Supergirl',
#  'Snake Eyes: G.I. Joe Origins',
#  'Brassic',
#  'Sons of Anarchy',
#  'Midsommar',
#  'Spencer',
#  'Chapelwaite',
#  'Dave Chappelle: The Closer',
#  'Avengers: Endgame',
#  'Cyrano',
#  'Blue Bloods',
#  'Wrath of Man',
#  'Community',
#  'The Duff',
#  "NCIS: Hawai'i",
#  'Family Guy',
#  'Evil',
#  'Tenet',
#  'Survive the Game',
#  'New Girl',
#  'Busanhaeng',
#  'FBI: International',
#  'Killing Eve',
#  'Dark',
#  'Hotel Transylvania: Transformania',
#  'Pretty Smart',
#  'Heels',
#  'Stargirl',
#  'This Is Us',
#  'Gladiator',
#  'Kota Factory',
#  'Escape Room: Tournament of Champions',
#  'The 100',
#  'GoldenEye',
#  'The Godfather',
#  'Rocketman',
#  'Chucky',
#  'Good Witch',
#  'Sex/Life',
#  'Beetle Juice',
#  'Magnum P.I.',
#  'Friendzone',
#  'The Nightmare Before Christmas',
#  'Interstellar',
#  'The Rocky Horror Picture Show',
#  'Pig',
#  'The Orville',
#  'Endeavour',
#  'Batoru rowaiaru',
#  'Homeland',
#  'Knock Knock',
#  'The Dark Knight',
#  'Two and a Half Men',
#  'The Protégé',
#  'Parks and Recreation',
#  'Star Trek: Lower Decks',
#  'One Piece: Wan pîsu',
#  'A Quiet Place Part II',
#  'Cobra Kai',
#  'FBI: Most Wanted',
#  "Don't Breathe 2",
#  'Wonder Woman 1984',
#  "Zack Snyder's Justice League",
#  'A Million Little Things',
#  'Reservation Dogs',
#  'Mad Men',
#  'The Goldbergs',
#  'Nobody',
#  'The Tomorrow War',
#  '1917',
#  'Sweet Home',
#  'Station 19',
#  'Law & Order',
#  'The Hunger Games',
#  "Jennifer's Body",
#  'Prison Break',
#  'Outer Banks',
#  'The Power of the Dog',
#  'Sherlock',
#  "Trick 'r Treat",
#  'Prisoners',
#  'Hereditary',
#  'Black as Night',
#  'The Good Girl',
#  'Dr. Death',
#  'It',
#  'The Father',
#  'Die Another Day',
#  'Call the Midwife',
#  'Inception',
#  'Doctor Sleep',
#  'Pulp Fiction',
#  'Ask 101',
#  'The Departed',
#  'Euphoria',
#  'The Umbrella Academy',
#  'Once Upon a Time',
#  'Reminiscence',
#  'Hollington Drive',
#  'Heartland',
#  'Boku no hîrô akademia',
#  'Scary Movie',
#  'South Park',
#  'Locke & Key',
#  'The Sinner',
#  'Fight Club',
#  'Rakka',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Help',
#  'Mean Girls',
#  'The Shining',
#  'Star Trek: Deep Space Nine',
#  'Dr. No',
#  'Hawaii Five-0',
#  'Arrow',
#  'Léon',
#  'The Manor',
#  'Bosch',
#  'South of Heaven',
#  'Legends of Tomorrow',
#  'Bingo Hell',
#  'Django Unchained',
#  'Zhang jin hu',
#  'Gone Girl',
#  "Bob's Burgers",
#  'Truth Be Told',
#  'Virgin River',
#  "If I Can't Have Love, I Want Power",
#  'SEAL Team',
#  'The Silence of the Lambs',
#  'Love & Other Drugs',
#  'Saturday Night Live',
#  'Star Trek: Discovery',
#  'Red Rocket',
#  'Scrubs',
#  'Hush',
#  'Line of Duty',
#  'Gunpowder Milkshake',
#  'Pleasure',
#  'Agents of S.H.I.E.L.D.',
#  'The Good Place',
#  'True Blood',
#  'Shadow and Bone',
#  'How to Get Away with Murder',
#  'Thir13en Ghosts',
#  'Mad Max: Fury Road',
#  'Mindhunter',
#  'Man on Fire',
#  'Tusk',
#  'Red Election',
#  'The World Is Not Enough',
#  'Halloweentown',
#  'Invincible',
#  'Chesapeake Shores',
#  'Star Trek: Voyager',
#  "On Her Majesty's Secret Service",
#  'Grown Ups',
#  'Fear Street: 1994',
#  'Goodfellas',
#  'Mom',
#  'The Big Leap',
#  'Inglourious Basterds',
#  'CODA',
#  'The Goonies',
#  'Murder, She Wrote',
#  'The Fifth Element',
#  'The L Word: Generation Q',
#  'Once Upon a Time in America',
#  'Wentworth',
#  'Demon Slayer: Kimetsu No Yaiba',
#  '30 Rock',
#  'BoJack Horseman',
#  'Scaredy Cats',
#  'Nightbooks',
#  'Acapulco',
#  'The Lighthouse',
#  'Psych',
#  'NCIS: Los Angeles',
#  'Columbo',
#  'The Courier',
#  'Love Strikes Twice',
#  'Stargate SG-1',
#  'One Tree Hill',
#  'Luca',
#  'Ghost Ship',
#  'My Son',
#  'The Marvelous Mrs. Maisel',
#  'Antlers',
#  'Forrest Gump',
#  'Addams Family Values',
#  'Blindspot',
#  "He's All That",
#  'Kingsman: The Secret Service',
#  'The Conjuring',
#  'Oldeuboi',
#  'Live and Let Die',
#  'Corpse Bride',
#  'Gotham',
#  'Catch Me If You Can',
#  'Frasier',
#  'Home Economics',
#  'Twilight',
#  'Deadpool',
#  'The Eyes of Tammy Faye',
#  'Hacks',
#  'American Night',
#  'Bull',
#  'Spider-Man: Far from Home',
#  'Orange Is the New Black',
#  'Superman and Lois',
#  'Death in Paradise',
#  'Suicide Squad',
#  'Mayday',
#  'Fringe',
#  'American Psycho',
#  'Boss Level',
#  'Bohemian Rhapsody',
#  'La Venganza de las Juanas',
#  "La vie d'Adèle",
#  '24',
#  'Casper',
#  'Voyagers',
#  'Vera',
#  'Gaetmaeul Chachacha',
#  'The Tragedy of Macbeth',
#  'The Conjuring: The Devil Made Me Do It',
#  'Arrested Development',
#  'Boardwalk Empire',
#  'Spartacus: Blood and Sand',
#  'A Clockwork Orange',
#  'All Creatures Great and Small',
#  'Modern Love',
#  'For All Mankind',
#  'Zombieland: Double Tap',
#  'Hubie Halloween',
#  'Those Who Wish Me Dead',
#  'After',
#  "Hitman's Wife's Bodyguard",
#  "Ron's Gone Wrong",
#  'The Premise',
#  'Narcos',
#  'Prisoners of the Ghostland',
#  'Back to the Future',
#  'Young Frankenstein',
#  'Élite',
#  'Avatar: The Last Airbender',
#  'Halloween III: Season of the Witch',
#  'Avengers: Infinity War',
#  'Justified',
#  'Wind River',
#  'Wu-Tang: An American Saga',
#  'The School of Rock',
#  'Scorpion',
#  'Final Space',
#  'Hellraiser',
#  'Hall Pass',
#  'D.P.',
#  'House of Cards',
#  'Guardians of the Galaxy',
#  'Stillwater',
#  'Alien',
#  'Se7en',
#  'Thor: Ragnarok',
#  'Space Jam: A New Legacy',
#  'Tomorrow Never Dies',
#  'Druk',
#  'Captain Marvel',
#  'Godzilla vs. Kong',
#  "Gerald's Game",
#  'Jurassic Park',
#  "That '70s Show",
#  'Something Borrowed',
#  'The Golden Girls',
#  'The Leftovers',
#  'The Mentalist',
#  'Naruto: Shippûden',
#  'No Country for Old Men',
#  'Goldfinger',
#  'The Other Two',
#  'Blade Runner',
#  'The Killing',
#  'Smallville',
#  'Jack Ryan',
#  'Monk',
#  'The Forever Purge',
#  'John Wick',
#  'Gunsmoke',
#  'The Girl with the Dragon Tattoo',
#  "She's All That",
#  'Jaws',
#  'Star Wars: Episode IX - The Rise of Skywalker',
#  'Lupin',
#  'Little House on the Prairie',
#  'The Gentlemen',
#  'Halloween 4: The Return of Michael Myers',
#  "Schindler's List",
#  'The Matrix Reloaded',
#  'Legacies',
#  'The Blue Lagoon',
#  '9-1-1: Lone Star',
#  'Little Shop of Horrors',
#  'The Holiday',
#  'Cats',
#  'Murdoch Mysteries',
#  'Forever Rich',
#  'Mr. Corman',
#  'The Dark Knight Rises',
#  'The Little Things',
#  'The Evil Dead',
#  'A Quiet Place',
#  'The Originals',
#  'Desperate Housewives',
#  "The Dead Don't Die",
#  'Army of the Dead',
#  'PAW Patrol: The Movie',
#  "A Knight's Tale",
#  'Why Women Kill',
#  'Fifty Shades of Grey',
#  'Big Little Lies',
#  'Emma.',
#  'Arrival',
#  'Spider-Man: Homecoming',
#  'Poirot',
#  'Eyes Wide Shut',
#  "Everybody's Talking About Jamie",
#  'Ready Player One',
#  'Glee',
#  'Diana',
#  'Edward Scissorhands',
#  'The Internship',
#  'Anna',
#  'Hanma Baki: Son of Ogre',
#  'The Birds',
#  'Call Me by Your Name',
#  'Get Out',
#  'Spider-Man 3',
#  'The Craft',
#  'Black Panther',
#  'White Collar',
#  'Ten Year Old Tom',
#  'Die Hard',
#  'Mass',
#  'Jaguar',
#  'Birds of Paradise',
#  'A Discovery of Witches',
#  "Don't Breathe",
#  "We're the Millers",
#  'Saving Private Ryan',
#  'The Grand Budapest Hotel',
#  'Ida Red',
#  'The VVitch: A New-England Folktale',
#  'Letterkenny',
#  'The King',
#  'Ready or Not',
#  'Green Lantern',
#  'Nomadland',
#  'Barry Lyndon',
#  'Retfærdighedens ryttere',
#  'The Hangover',
#  'Raya and the Last Dragon',
#  'The Amazing Spider-Man',
#  'Final Destination',
#  'The West Wing',
#  'Donnie Darko',
#  'Shershaah',
#  'Person of Interest',
#  'Leverage',
#  'The O.C.',
#  'His Dark Materials',
#  'Married with Children',
#  'The Good Wife',
#  'Licence to Kill',
#  'Grave',
#  'Harry Potter and the Goblet of Fire',
#  'Freaky',
#  'The Cleaner',
#  'Grace and Frankie',
#  'Madres',
#  'Shutter Island',
#  'Harry Potter and the Deathly Hallows: Part 2',
#  'Avatar',
#  'The Flight Attendant',
#  'The Princess Bride',
#  'Super Mario Bros.',
#  'Elementary',
#  'Star Trek: Picard',
#  'Scream 2',
#  'A.P. Bio',
#  'Into the Night',
#  'In the Dark',
#  'The Hunt',
#  'Tomb Raider',
#  'The Prestige',
#  'Spider-Man: Into the Spider-Verse',
#  'Orphan',
#  'Jumper',
#  'Banshee',
#  'Atypical',
#  "God's Not Dead: We the People",
#  'Us',
#  'Sicario',
#  'Whiplash',
#  'Sabrina the Teenage Witch',
#  'Boogie Nights',
#  'Deadpool 2',
#  'Copshop',
#  'It Chapter Two',
#  'Another Life',
#  'Taboo',
#  'Sweet Girl',
#  'Star Wars: The Clone Wars',
#  'One Summer',
#  'Miracle Workers',
#  'Pride & Prejudice',
#  'Most Dangerous Game',
#  '13 Reasons Why',
#  'News of the World',
#  'The Great Gatsby',
#  'Thalaivi',
#  'The Green Mile',
#  'The Texas Chain Saw Massacre',
#  'Fleabag',
#  'Official Secrets',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Pretty Little Liars',
#  'Man of Steel',
#  'Live by Night',
#  'In Time',
#  'The Social Network',
#  'Hamilton',
#  'Raised by Wolves',
#  'Queen of the South',
#  'Power Book III: Raising Kanan',
#  'Halloween H20: 20 Years Later',
#  'The Big Short',
#  'Prometheus',
#  'Project X',
#  'The Sixth Sense',
#  'From Russia with Love',
#  'Never Have I Ever',
#  'The Good Fight',
#  'Dear White People',
#  'Roswell, New Mexico',
#  'Sweet Tooth',
#  'Pose',
#  "Dawson's Creek",
#  'Nocturnal Animals',
#  'The Man in the High Castle',
#  'Mars Attacks!',
#  'The Devil All the Time',
#  'Sen to Chihiro no kamikakushi',
#  'Practical Magic',
#  'Cheers',
#  'Chilling Adventures of Sabrina',
#  'The Lost Boys',
#  'Chaos Walking',
#  'The Cabin in the Woods',
#  'Troy',
#  'Jumanji: The Next Level',
#  'Taxi Driver',
#  'Spiral: From the Book of Saw',
#  'Our Kind of People',
#  'Tokyo Revengers',
#  'Motherland: Fort Salem',
#  'Nightcrawler',
#  'Malcolm in the Middle',
#  'After We Collided',
#  'Black Swan',
#  'Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn',
#  'The Greatest Showman',
#  'Scarface',
#  'Requiem for a Dream',
#  'Tacoma FD',
#  'All American',
#  'The Americans',
#  '3%',
#  'Unforgotten',
#  'The Haunted Mansion',
#  'American Beauty',
#  'Mumbai Diaries 26/11',
#  'Legally Blonde',
#  'Ex Machina',
#  'Last Man Standing',
#  'Narcos: México',
#  'Love, Death & Robots',
#  'Harry Potter and the Chamber of Secrets',
#  "Mythic Quest: Raven's Banquet",
#  'Saw',
#  'Good Will Hunting',
#  'Halloween: Resurrection',
#  'Psycho',
#  'Doogie Kamealoha, M.D.',
#  'Hacksaw Ridge',
#  'The Revenant',
#  'Fear Street: 1978',
#  'Coraline',
#  'Vivo',
#  'The Nevers',
#  'The Conners',
#  'Logan',
#  'Jojo Rabbit',
#  'Dazed and Confused',
#  'The Chair',
#  'One Hour Photo',
#  'Walker',
#  'Top Gun',
#  'Idi i smotri',
#  'The Larkins',
#  'Six Feet Under',
#  'Men in Black',
#  'The Lord of the Rings: The Return of the King',
#  'Britannia',
#  'Small Engine Repair',
#  'Toma',
#  'Star Wars',
#  'The Stand',
#  'Death Note: Desu nôto',
#  'On the Verge',
#  'Clueless',
#  'Baby Driver',
#  'The Ice Road',
#  'Harry Potter and the Prisoner of Azkaban',
#  'The Outsiders',
#  'The Lost Daughter',
#  'Escape the Undertaker',
#  'Scott Pilgrim vs. the World',
#  'The Mauritanian',
#  'American Pie',
#  'Halloween 5: The Revenge of Michael Myers',
#  '12 Angry Men',
#  'Death Proof',
#  'Atonement',
#  'Longmire',
#  'Suedi',
#  'NCIS: New Orleans',
#  'Naruto',
#  'Moonrise Kingdom',
#  'Clue',
#  'El hoyo',
#  'In the Heights',
#  'Kamisama no iu tôri',
#  'Altered Carbon',
#  'SAS: Red Notice',
#  'What Is Life Worth',
#  'Scary Stories to Tell in the Dark',
#  'Enterprise',
#  'Deadwood',
#  'No Sudden Move',
#  'The Neighborhood',
#  'Barry',
#  'The Irishman',
#  'Step Brothers',
#  'BAC Nord',
#  'Charlie and the Chocolate Factory',
#  'Broadchurch',
#  'Dunkirk',
#  'Firefly',
#  'Aquaman',
#  'Cashback',
#  'The Boss Baby: Family Business',
#  'The Living Daylights',
#  '28 Days Later...',
#  'The King of Queens',
#  'American Dad!',
#  'Night Hunter',
#  'Love and Monsters',
#  'The Bold Type',
#  'Doctor Strange',
#  'Soul',
#  'Avengers: Age of Ultron',
#  'Silicon Valley',
#  'There Will Be Blood',
#  'Maleficent',
#  'Cars',
#  'Beverly Hills, 90210',
#  'Designated Survivor',
#  'Oz',
#  'Premonition',
#  'A Nightmare on Elm Street 3: Dream Warriors',
#  'SpongeBob SquarePants',
#  'iZombie',
#  'The Great British Bake Off',
#  'Iron Man',
#  'The Village',
#  'Hunter x Hunter',
#  'Fuimos canciones',
#  'Private Practice',
#  '300',
#  'Thor',
#  'The Lobster',
#  'Transformers',
#  'Batwoman',
#  'The Chosen',
#  'Ray Donovan',
#  'Sense8',
#  'The Boy in the Striped Pyjamas',
#  'Annette',
#  'Training Day',
#  'The VelociPastor',
#  'Raiders of the Lost Ark',
#  'CSI: Miami',
#  'Pearl Harbor',
#  'Matilda',
#  'The Amazing Spider-Man 2',
#  'Love Life',
#  'Coco',
#  'Desperado',
#  'Judas and the Black Messiah',
#  'Grimm',
#  'Gomorra: La serie',
#  'Alita: Battle Angel',
#  'The Godfather: Part II',
#  'Pitch Perfect',
#  'Prodigal Son',
#  'Captain America: The First Avenger',
#  'The Dreamers',
#  'Babylon 5',
#  'American Gods',
#  'Futurama',
#  'The Dry',
#  'Eternal Sunshine of the Spotless Mind',
#  'Spider-Man 2',
#  'The Martian',
#  'StartUp',
#  'Scream 4',
#  'Jumanji',
#  'The Guest',
#  'Ah-ga-ssi',
#  'The Last of the Mohicans',
#  'The Medium',
#  'Watchmen',
#  'Aliens',
#  'Mother!',
#  'John Wick: Chapter 3 - Parabellum',
#  'Miraculous: Tales of Ladybug & Cat Noir',
#  'Green Book',
#  'Tommy Boy',
#  'Kill Bill: Vol. 1',
#  'It Follows',
#  'Gemini Man',
#  'Chuck',
#  'Vacation Friends',
#  'Snatch',
#  'Black Sails',
#  'Il buono, il brutto, il cattivo',
#  'The Notebook',
#  'Castlevania',
#  'The Hobbit: An Unexpected Journey',
#  'Split',
#  'Ginny & Georgia',
#  'Slasher',
#  'The Descent',
#  'The Usual Suspects',
#  'Edge of Tomorrow',
#  'Reign',
#  'Emily in Paris',
#  'Nancy Drew',
#  'Godfather of Harlem',
#  'Jolt',
#  'Layer Cake',
#  'Stardust',
#  'Tom & Jerry',
#  'Srpski film',
#  'The Matrix Revolutions',
#  'The Kominsky Method',
#  'Cast Away',
#  'Power',
#  'Shetland',
#  "One Flew Over the Cuckoo's Nest",
#  'Jujutsu Kaisen',
#  'Nanatsu no taizai',
#  'Drive',
#  'Batman Begins',
#  '2001: A Space Odyssey',
#  'The Black Phone',
#  'Resident Alien',
#  'E.T. the Extra-Terrestrial',
#  'Furia',
#  'Hotel Transylvania',
#  'The End of the F***ing World',
#  'Sinister',
#  'The Nanny',
#  'The Lovely Bones',
#  'Oculus',
#  'Into the Wild',
#  'The Newsroom',
#  'The Ring',
#  'Brokeback Mountain',
#  'The Cave',
#  'The Big Lebowski',
#  'Rome',
#  'Adult Material',
#  'Mulholland Dr.',
#  'Uncut Gems',
#  "Miss Peregrine's Home for Peculiar Children",
#  'Hidden Figures',
#  'Cloud Atlas',
#  'Carnival Row',
#  'Incendies',
#  'Bhoot Police',
#  'Alias',
#  'Luna Park',
#  'Monster House',
#  'Belfast',
#  'The Outsider',
#  'United States of Al',
#  'Imposters',
#  'Bron/Broen',
#  'Crimson Peak',
#  'Trainspotting',
#  'Adventure Time',
#  'Black Hawk Down',
#  'Freedom Writers',
#  'Extraction',
#  'Host',
#  'Elvira: Mistress of the Dark',
#  'The Andy Griffith Show',
#  'The Blues Brothers',
#  'Apocalypse Now',
#  'My Life Is Murder',
#  'Bad Sport',
#  'Almost Famous',
#  'Coming Home in the Dark',
#  'The Great',
#  'V for Vendetta',
#  'Guardians of the Galaxy Vol. 2',
#  'Ang-ma-reul bo-at-da',
#  'Palm Springs',
#  'The Mask',
#  'Ford v Ferrari',
#  'Braveheart',
#  'From Dusk Till Dawn',
#  'Veep',
#  'Memento',
#  'Moana',
#  'Kingsman: The Golden Circle',
#  'The Way Way Back',
#  'Jack Reacher',
#  'The Hateful Eight',
#  'Respect',
#  'The Babysitter',
#  'Fantastic Mr. Fox',
#  'Pretty Woman',
#  'The IT Crowd',
#  "Pan's Labyrinth",
#  'La La Land',
#  'Anne',
#  'Mr. & Mrs. Smith',
#  'Queen of the Damned',
#  'Upload',
#  'Halloween: The Curse of Michael Myers',
#  'Rizzoli & Isles',
#  'Luther',
#  'The Witcher: Nightmare of the Wolf',
#  'Jane the Virgin',
#  'Black Clover',
#  'Benedetta',
#  'Enemy',
#  'Departure',
#  'Me Before You',
#  'Way Down',
#  'Level 16',
#  'Robin Hood: Prince of Thieves',
#  'Kaubôi bibappu',
#  'Harry Potter and the Order of the Phoenix',
#  'Logan Lucky',
#  'American History X',
#  'Grease',
#  'Dead to Me',
#  'Yesterday',
#  'Girls',
#  'Jurassic World',
#  'Knight and Day',
#  'The Town',
#  'Bridesmaids',
#  'Road House',
#  'Thunderball',
#  'A View to a Kill',
#  'The Accountant',
#  'Mayans M.C.',
#  'Demonic',
#  'Justice League',
#  'Cold Case',
#  'The Righteous Gemstones',
#  'Les Misérables',
#  'Irréversible',
#  'Star Wars: Episode I - The Phantom Menace',
#  'Will & Grace',
#  'Home Alone',
#  'Malèna',
#  'Good Boys',
#  'Scandal',
#  'The Truman Show',
#  'Never Say Never Again',
#  'Maleficent: Mistress of Evil',
#  'The Love Boat',
#  'Happy Endings',
#  'Burn Notice',
#  'Harry Potter and the Deathly Hallows: Part 1',
#  'Children of the Corn',
#  'After Life',
#  'The Deuce',
#  'Possession',
#  'Servant',
#  'Mission: Impossible - Fallout',
#  'Gods of Egypt',
#  'Basic Instinct',
#  'Wild Wild West',
#  'Independence Day',
#  'Girl in the Basement',
#  'Extracurricular',
#  'Good Omens',
#  'Kimetsu no Yaiba: Mugen Ressha-Hen',
#  '3rd Rock from the Sun',
#  'Younger',
#  'Jumanji: Welcome to the Jungle',
#  'Shadowplay',
#  'The Texas Chainsaw Massacre',
#  'Lewis',
#  'Merlin',
#  'The Woman in the Window',
#  'X-Men',
#  'Signs',
#  'Gravity Falls',
#  'Scooby-Doo',
#  'The Tender Bar',
#  'Sin City',
#  'Fury',
#  ...]

# %% [markdown]
# #### 1.3.3. Dropping Movies with Duplicate Names
#
# Finally, use this `Name` list from 1.3.2 to drop all rows that correspond to a `Name` that had more than one row assigned to it. (Or in other words drop the movies that we considered "duplicates").
#
# How many additional rows did you drop?

# %%
def process(row):
    current_name = row['Name']
    if current_name in Names:
        return True
    else:
        return False
df_short['Name Exists'] = df_short.apply(process, axis=1)
df_short
# Out:
# C:\Users\samma\AppData\Local\Temp\ipykernel_17364\720513729.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_short['Name Exists'] = df_short.apply(process, axis=1)
#                                         Name  Rate  Date  Type  Name Exists
# 0                             No Time to Die   7.6  2021  Film         True
# 1                                 The Guilty   6.3  2021  Film        False
# 2                  The Many Saints of Newark   6.4  2021  Film         True
# 3                Venom: Let There Be Carnage   6.4  2021  Film         True
# 4                                       Dune   8.3  2021  Film        False
# ...                                      ...   ...   ...   ...          ...
# 6173  The Human Centipede II (Full Sequence)   3.8  2011  Film        False
# 6174                        Double Indemnity   8.3  1944  Film        False
# 6175      Before the Devil Knows You're Dead   7.3  2007  Film        False
# 6176                              Queen Bees   6.0  2021  Film        False
# 6177                              Death Race   6.3  2008  Film        False
#
# [5993 rows x 5 columns]

# %%
filtered_df = df_short[df_short['Name Exists'] != False]
filtered_df = filtered_df.drop('Name Exists', axis=1).reset_index()
filtered_df
# Out:
#       index                         Name  Rate  Date    Type
# 0         0               No Time to Die   7.6  2021    Film
# 1         2    The Many Saints of Newark   6.4  2021    Film
# 2         3  Venom: Let There Be Carnage   6.4  2021    Film
# 3         5                    Ted Lasso   8.8  2021  Series
# 4         6                     Free Guy   7.3  2021    Film
# ...     ...                          ...   ...   ...     ...
# 3428   3873                   Sinister 2   5.3  2015    Film
# 3429   3874          Weekend at Bernie's   6.4  1989    Film
# 3430   3875       È stata la mano di Dio   7.3  2021    Film
# 3431   3876                          Mud   7.4  2012    Film
# 3432   3877                  La pianiste   7.5  2001    Film
#
# [3433 rows x 5 columns]

# %% [markdown]
# Dropped 2560 rows

# %% [markdown]
# ## 2. ReelView Dataset
#
# ### 2.1. Reading the csv
#
# 1. Read the `ReelView.csv` into a dataframe. The strings that are used to represent missing values in this csv file are "". So your pd.read_csv() function should automatically convert these values to NaN without you having to specify that "" is a missing value string.
# 2. Show the first 5 rows.
# 3. Show how many rows this dataframe has.

# %%
df_real = pd.read_csv("C:\\Users\\samma\\Documents\\stat207\\saraza2\\lab_04\\ReelView.csv", na_values="")
df_real.head()
# Out:
#                  title  release_date                director  \
# 0  Terms of Endearment        1983.0         James L. Brooks
# 1                 1917        2019.0              Sam Mendes
# 2    Spies in Disguise        2019.0  Nick Bruno, Troy Quane
# 3           Just Mercy        2019.0   Destin Daniel Cretton
# 4         Little Women        2019.0            Greta Gerwig
#
#                                                 cast
# 0  Shirley MacLaine, Debra Winger, Jack Nicholson...
# 1                George MacKay, Dean-Charles Chapman
# 2  Will Smith, Tom Holland, Rashida Jones, Ben Me...
# 3  Michael B. Jordan, Jamie Foxx, Brie Larson, Ti...
# 4  Saoirse Ronan, Chris Cooper, Louis Garrel, Jam...

# %%
df_real.shape[0]
# Out:
# 3990

# %% [markdown]
# ### 2.2. Missing Value Cleaning
# 1. First create a dataframe that only contains the the columns that we care about for this pre-analsys: `title`, `release_date`, and `cast`.
# 2. Then drop all rows with NaN values from this dataframe.
# 3. How many rows did we drop?

# %%
df_prean = df_real[['title', 'release_date', 'cast']]
df_prean
# Out:
#                      title  release_date  \
# 0      Terms of Endearment        1983.0
# 1                     1917        2019.0
# 2        Spies in Disguise        2019.0
# 3               Just Mercy        2019.0
# 4             Little Women        2019.0
# ...                    ...           ...
# 3985  Music of Chance, The        1993.0
# 3986           Ultraviolet        2006.0
# 3987               Speed 2        1997.0
# 3988               Ex, The        2007.0
# 3989                 Venus        2006.0
#
#                                                    cast
# 0     Shirley MacLaine, Debra Winger, Jack Nicholson...
# 1                   George MacKay, Dean-Charles Chapman
# 2     Will Smith, Tom Holland, Rashida Jones, Ben Me...
# 3     Michael B. Jordan, Jamie Foxx, Brie Larson, Ti...
# 4     Saoirse Ronan, Chris Cooper, Louis Garrel, Jam...
# ...                                                 ...
# 3985  Mandy Patinkin, James Spader, M. Emmet Walsh, ...
# 3986  Milla Jovovich, Cameron Bright, Nick Chinlund,...
# 3987  Sandra Bullock, Jason Patric, Willem Dafoe, Te...
# 3988  Zach Braff, Amanda Peet, Jason Bateman, Charle...
# 3989  Peter O'Toole, Jodie Whittaker, Leslie Phillip...
#
# [3990 rows x 3 columns]

# %%
df_prean = df_prean.dropna()
df_prean
# Out:
#                      title  release_date  \
# 0      Terms of Endearment        1983.0
# 1                     1917        2019.0
# 2        Spies in Disguise        2019.0
# 3               Just Mercy        2019.0
# 4             Little Women        2019.0
# ...                    ...           ...
# 3985  Music of Chance, The        1993.0
# 3986           Ultraviolet        2006.0
# 3987               Speed 2        1997.0
# 3988               Ex, The        2007.0
# 3989                 Venus        2006.0
#
#                                                    cast
# 0     Shirley MacLaine, Debra Winger, Jack Nicholson...
# 1                   George MacKay, Dean-Charles Chapman
# 2     Will Smith, Tom Holland, Rashida Jones, Ben Me...
# 3     Michael B. Jordan, Jamie Foxx, Brie Larson, Ti...
# 4     Saoirse Ronan, Chris Cooper, Louis Garrel, Jam...
# ...                                                 ...
# 3985  Mandy Patinkin, James Spader, M. Emmet Walsh, ...
# 3986  Milla Jovovich, Cameron Bright, Nick Chinlund,...
# 3987  Sandra Bullock, Jason Patric, Willem Dafoe, Te...
# 3988  Zach Braff, Amanda Peet, Jason Bateman, Charle...
# 3989  Peter O'Toole, Jodie Whittaker, Leslie Phillip...
#
# [3694 rows x 3 columns]

# %%
row_num = len(df_real) - len(df_prean)
row_num
# Out:
# 296

# %% [markdown]
# ### 2.3. Duplicate Name Cleaning
#
# #### 2.3.1. List of Non-Duplicated Movie Names
#
# Create a list of all movie `title`s in this dataframe that have ONLY ONE ROW in the dataset that corresponds to it.

# %%
title_count = {}
Titles = []
duplicated_titles = df_prean['title'].to_list()
for title in duplicated_titles:
    if title in title_count:
        val = title_count[title]
        val = val + 1
        title_count[title] = val
    else:
        title_count[title] = 1
for title, count in title_count.items():
    if count == 1:
        Titles.append(title)
Titles
# Out:
# ['Terms of Endearment',
#  '1917',
#  'Spies in Disguise',
#  'Just Mercy',
#  'Bombshell',
#  'Cats',
#  'Star Wars: The Rise of Skywalker',
#  'Uncut Gems',
#  'Richard Jewell',
#  'Fanboys',
#  "He's Just Not That Into You",
#  'Uninvited, The',
#  'New in Town',
#  'Taken',
#  'Underworld: Rise of the Lycans',
#  'Moscow, Belgium',
#  'Inkheart',
#  'Siege, The',
#  'In the Valley of Elah',
#  'Oblivion',
#  'To the Wonder',
#  'Hunter, The',
#  'Disconnect',
#  '42',
#  'Tyrannosaur',
#  'Trance',
#  'Evil Dead',
#  'Host, The',
#  'Place Beyond the Pines, The',
#  'Whisper of the Heart',
#  'Ophelia',
#  'Yesterday',
#  'Annabelle Comes Home',
#  "Child's Play",
#  'Toy Story 4',
#  'French Connection, The',
#  'Men in Black International',
#  'Shaft',
#  'Plus One',
#  'Outlaw King',
#  "Girl in the Spider's Web, The",
#  'Grinch, The',
#  'Boy Erased',
#  'Can You Ever Forgive Me?',
#  'Time Trap',
#  'Unlovable',
#  'Nutcracker and the Four Realms, The',
#  'Bohemian Rhapsody',
#  'Free Solo',
#  "National Lampoon's Christmas Vacation",
#  'Revolutionary Road',
#  'Mighty Aphrodite',
#  'Autumn in New York',
#  'Brady Bunch Movie, The',
#  'Atonement',
#  'Under the Same Moon',
#  'Polar Express, The',
#  'Bee Season',
#  'Intruder, The',
#  'Long Shot',
#  'Stalker',
#  'JT LeRoy',
#  'Avengers: Endgame',
#  'Last Hour, The',
#  'Curse of La Llorona, The',
#  'Under the Silver Lake',
#  'Red Joan',
#  'Beastly',
#  'Adjustment Bureau, The',
#  'Drive Angry',
#  'Hall Pass',
#  'I Am Number Four',
#  'Unknown',
#  'Just Go with It',
#  'Cedar Rapids',
#  'Behind the Mask',
#  'Sanctum',
#  'Perfect Stranger',
#  'This Film Is Not Yet Rated',
#  'Turistas',
#  'Flash of Genius',
#  'Talk to Her',
#  'Rosewood',
#  'Carrington',
#  'Civil Action, A',
#  'Reaping, The',
#  'Proposition, The',
#  'Stop-Loss',
#  'Heart of the Game, The',
#  'Robots',
#  'Gran Torino',
#  'Two Weeks Notice',
#  'Anastasia',
#  'Alien',
#  'Bridges of Madison County, The',
#  'Hollywoodland',
#  'Stepfather, The',
#  'Pacific Rim Uprising',
#  'Unsane',
#  'Madame',
#  'I Kill Giants',
#  'Castle in the Sky',
#  'Allure',
#  'Death of Stalin, The',
#  'Love, Simon',
#  'Mountain Between Us, The',
#  'Florida Project, The',
#  'Osiris Child, The',
#  'Blade Runner 2049',
#  'Flatliners',
#  'Battle of the Sexes',
#  'Realive',
#  'Mark Felt',
#  'American Made',
#  'Expendables, The',
#  'Eat Pray Love',
#  'Scott Pilgrim vs. the World',
#  'Cairo Time',
#  'Other Guys, The',
#  'Charlie St. Cloud',
#  'Countdown to Zero',
#  'Dinner for Schmucks',
#  'Kids Are All Right, The',
#  'My Neighbor Totoro',
#  'Sicario: Day of the Soldado',
#  'Izzy Gets the F*ck Across Town',
#  'Beach House',
#  'Jurassic World: Fallen Kingdom',
#  'Tag',
#  'Incredibles 2',
#  'Valley, The',
#  'Kite Runner, The',
#  'Manon des Sources',
#  'Just Friends',
#  'Guess Who',
#  'Blade',
#  'One Fine Day',
#  'Lust, Caution',
#  'Four Rooms',
#  'Bewitched',
#  'Electrical Life of Louis Wain, The',
#  'Dune: Part One',
#  'Last Duel, The',
#  'Halloween Kills',
#  'Lamb',
#  'No Time to Die',
#  'Many Saints of Newark, The',
#  'Venom: Let There Be Carnage',
#  'Addams Family 2, The',
#  'Dear Evan Hansen',
#  'Jimmy Hollywood',
#  'Martian Child',
#  'Austin Powers: International Man of Mystery',
#  'Women, The',
#  'Fly Away Home',
#  'Priest',
#  "Charlie's Angels",
#  'Insidious',
#  'Source Code',
#  'Sucker Punch',
#  'Paul',
#  'Limitless',
#  'Lincoln Lawyer, The',
#  'Red Riding Hood',
#  'Battle Los Angeles',
#  'Rango',
#  'Cruella',
#  'Quiet Place Part II, A',
#  'Final Account',
#  'Army of the Dead',
#  'Woman in the Window, The',
#  'Spiral',
#  'Those Who Wish Me Dead',
#  'Profile',
#  'Oxygen',
#  'Wrath of Man',
#  'Kingdom, The',
#  'Fantastic Four, The',
#  'Volver',
#  'Eternal',
#  'Mad Love',
#  'La Vie en Rose',
#  'Hostel',
#  'Water',
#  'Hand of God, The',
#  'West Side Story',
#  'National Champions',
#  'Being the Ricardos',
#  'Benedetta',
#  'Power of the Dog, The',
#  'Wolf',
#  'Superman III',
#  'Encanto',
#  'Swan, The',
#  'Mile 22',
#  "What's Up Doc?",
#  'Crazy Rich Asians',
#  "Never Goin' Back",
#  'Meg, The',
#  'BlacKkKlansman',
#  'Spy Who Dumped Me, The',
#  'Darkest Minds, The',
#  'Sin Reaper',
#  'Color of Money, The',
#  'Sure Thing, The',
#  'Hangover, The',
#  'My Life in Ruins',
#  'Land of the Lost',
#  'Away We Go',
#  'Kiss of the Spider Woman',
#  'Out of Africa',
#  'Drag Me to Hell',
#  'Up',
#  'War of the Roses, The',
#  'Big Fan',
#  'Taking Woodstock',
#  'Born on the Fourth of July',
#  'Post Grad',
#  'Inglourious Basterds',
#  'Abyss, The',
#  'Ponyo',
#  "Time Traveler's Wife, The",
#  'Absolutely Fabulous - The Movie',
#  'Ghostbusters',
#  'Infiltrator, The',
#  'Secret Life of Pets, The',
#  'Mike and Dave Need Wedding Dates',
#  'Legend of Tarzan, The',
#  'BFG, The',
#  'Purge, The: Election Year',
#  'Independence Day: Resurgence',
#  'Neon Demon, The',
#  'Violent Night',
#  "Lady Chatterley's Lover",
#  'Son, The',
#  'Glass Onion',
#  'Bones and All',
#  'Fabelmans, The',
#  'She Said',
#  'Menu, The',
#  'Wonder, The',
#  'Black Panther: Wakanda Forever',
#  'Deep Impact',
#  'Astronaut Farmer, The',
#  'Prom Night',
#  'Grizzly Man',
#  'Congo',
#  'I Am Sam',
#  'Armageddon',
#  'Avenue Montaigne',
#  'Smart People',
#  'Change-Up, The',
#  'Crazy, Stupid, Love.',
#  'Cowboys &amp; Aliens',
#  'Captain America: The First Avenger',
#  'Terri',
#  'Friends with Benefits',
#  'Tabloid',
#  'Harry Potter and the Deathly Hallows Part 2',
#  'Horrible Bosses',
#  'Zookeeper',
#  'Noble House',
#  'Lego Movie 2, The: The Second Part',
#  'Cold Pursuit',
#  'What Men Want',
#  'Untogether',
#  'Miss Bala',
#  'Piercing',
#  'Dark Knight, The',
#  'Object of My Affection, The',
#  'Rush Hour 2',
#  'Million Dollar Baby',
#  'Mamma Mia!',
#  "You've Got Mail",
#  'Richard III',
#  'Napoleon Dynamite',
#  'Judy',
#  'Kramer vs. Kramer',
#  'Rambo: Last Blood',
#  'Ad Astra',
#  'Downton Abbey',
#  'Hustlers',
#  'Goldfinch, The',
#  'It: Chapter 2',
#  "Don't Let Go",
#  'Mrs. Brown',
#  'Matrix Revolutions, The',
#  'Walk Hard: The Dewey Cox Story',
#  'Speed Racer',
#  'Sentinel, The',
#  'Dogville',
#  'Chicago',
#  'Exodus: Gods and Kings',
#  'Wild',
#  'Diplomacy',
#  'Horrible Bosses 2',
#  'Hunger Games, The: Mockingjay - Part 1',
#  'Rosewater',
#  'Foxcatcher',
#  'Dumb and Dumber To',
#  'Theory of Everything, The',
#  'Laggies',
#  'Meet the Robinsons',
#  'Deception',
#  'Jacket, The',
#  'House of Wax',
#  'Boiler Room, The',
#  'Center Stage',
#  'Michael Clayton',
#  'Harold and Kumar Escape from Guantanamo Bay',
#  '88 Minutes',
#  'Fall, The',
#  'Melinda, Melinda',
#  'Hudsucker Proxy, The',
#  'Sixth Sense, The',
#  'Grumpy Old Men',
#  'Bourne Ultimatum, The',
#  'Forgetting Sarah Marshall',
#  "Devil's Own, The",
#  'Mr. and Mrs. Smith',
#  'Ice Age',
#  'Jingle All the Way',
#  'Wallace &amp; Gromit: The Curse of the Were-Rabbit',
#  'Seven Pounds',
#  'Dr. T and the Women',
#  'Star Trek V: The Final Frontier',
#  'Tora! Tora! Tora!',
#  'Miracle on 34th Street',
#  'War of the Worlds',
#  'Maria, Full of Grace',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Shrek the Third',
#  'Joe vs. the Volcano',
#  'Prairie Home Companion, A',
#  'Collateral',
#  'U.S. Marshals',
#  'Lilya 4-Ever',
#  'Harry Potter and the Goblet of Fire',
#  'Forest, The',
#  'Point Break',
#  'Joy',
#  'Concussion',
#  'Revenant, The',
#  'Hateful Eight, The',
#  'Big Short, The',
#  'Youth',
#  'Star Wars: The Force Awakens',
#  'Star Wars: Return of the Jedi',
#  'Last Airbender, The',
#  'Killer Inside Me, The',
#  'I Am Love',
#  'Grown Ups',
#  'Knight and Day',
#  "Winter's Bone",
#  'Jonah Hex',
#  'Toy Story 3',
#  'Cyrus',
#  'A-Team, The',
#  'Last Broadcast, The',
#  'No Country for Old Men',
#  'Dukes of Hazzard, The',
#  "Hitchhiker's Guide to the Galaxy, The",
#  'Unborn, The',
#  "Devil's Advocate, The",
#  'Close Encounters of the Third Kind',
#  'Things We Lost in the Fire',
#  'I, Robot',
#  'Robin Hood',
#  'Letters to Juliet',
#  'Iron Man 2',
#  'Harry Brown',
#  'Losers, The',
#  'Dead Again',
#  'Greatest Game Ever Played, The',
#  'Boy in the Striped Pajamas,The',
#  'Outside Providence',
#  'Mansfield Park',
#  'Fly, The',
#  'Jumper',
#  'High Tension',
#  'Wilde Wedding, The',
#  'Home Again',
#  'Anti-Matter',
#  'Limehouse Golem, The',
#  'It',
#  'Tulip Fever',
#  'Goon: Last of the Enforcers',
#  'Temple',
#  'Layover, The',
#  "My Best Friend's Wedding",
#  'Imagine Me &amp; You',
#  'Man of the House',
#  'Much Ado About Nothing',
#  'Romulus, My Father',
#  'Lookout, The',
#  'He Was a Quiet Man',
#  'Amelie',
#  'In Search of a Midnight Kiss',
#  'Scary Movie',
#  'Lucky Ones, The',
#  'Starship Troopers',
#  'Donnie Darko',
#  "Astronaut's Wife, The",
#  'Owning Mahowny',
#  'Ten, The',
#  'Scary Movie 2',
#  'Choke',
#  'Miami Vice',
#  'Transporter, The',
#  'Love &amp; Basketball',
#  'Sexy Beast',
#  'Basquiat',
#  'Fracture',
#  'Mostly Martha',
#  'Miss Potter',
#  'Transporter 2',
#  'Clerks',
#  'Transporter 3',
#  'Matchmaker, The',
#  'Kill Bill (Volume 2)',
#  'Clerks II',
#  'Look at Me (Comme une image)',
#  'Four Christmases',
#  'Cashback',
#  'Life Before Her Eyes, The',
#  'Shall We Dance?',
#  'Oliver Twist',
#  'Matilda',
#  'Control',
#  'Mist, The',
#  'Joyeux Noel (Merry Christmas)',
#  'Racing Stripes',
#  'Irreversible',
#  'Princess Mononoke',
#  'Vacancy',
#  'Die Another Day',
#  'Kung-Fu Panda',
#  'X-Files, The: I Want to Believe',
#  'Spirited Away',
#  'Kiss the Girls',
#  'Spirit, The',
#  'Deconstructing Harry',
#  'Peacemaker, The',
#  'Blair Witch Project 2, The: Book of Shadows',
#  'Crouching Tiger, Hidden Dragon',
#  'Black Book',
#  'Nightmare Before Christmas, The',
#  'Chicken Little',
#  'Marley &amp; Me',
#  'Buffalo Soldiers',
#  'Pianist, The',
#  'Paradise Road',
#  'King of the Hill',
#  'Messengers, The',
#  'Take the Lead',
#  'Religulous',
#  'American Psycho',
#  'Secretary',
#  'District 9',
#  'Cold Souls',
#  'Paper Heart',
#  'Julie &amp; Julia',
#  'G.I. Joe: The Rise of Cobra',
#  'Gorillas in the Mist',
#  'Perfect Getaway, A',
#  'In the Loop',
#  'Dangerous Liaisons',
#  'Funny People',
#  'Till',
#  'Armageddon Time',
#  'Tar',
#  'Good Nurse, The',
#  'Ticket to Paradise',
#  'Black Adam',
#  'Banshees of Inisherin, The',
#  'Triangle of Sadness',
#  'Halloween Ends',
#  'Amsterdam',
#  '127 Hours',
#  "Girl Who Kicked the Hornet's Nest, The",
#  'Monsters',
#  'Paranormal Activity 2',
#  'Hereafter',
#  'Stone',
#  'Conviction',
#  'Red',
#  "It's Kind of a Funny Story",
#  'Life as We Know It',
#  'Chandni Chowk to China',
#  'Traffic',
#  'Prophecy, The',
#  'Deep Blue Sea',
#  '30 Days of Night',
#  'Without a Paddle',
#  'Enron: The Smartest Guys in the Room',
#  'Last Action Hero',
#  'Paul Blart: Mall Cop',
#  'Primal Fear',
#  'Wonder',
#  'Roman J. Israel, Esq.',
#  'Man Who Invented Christmas, The',
#  'Three Billboards Outside Ebbing, Missouri',
#  'Coco',
#  'Darkest Hour',
#  'Mudbound',
#  'Full Metal Jacket',
#  'Sweet Virginia',
#  'Justice League',
#  'Manchurian Candidate, The',
#  'Full Monty, The',
#  'National Treasure: Book of Secrets',
#  'Platoon',
#  'Talladega Nights',
#  'Rachel Getting Married',
#  'Rules of Attraction, The',
#  'Read My Lips',
#  'Beloved',
#  'Harry Potter and the Half-Blood Prince',
#  'I Love You, Beth Cooper',
#  'Bruno',
#  'Lethal Weapon',
#  'Moon',
#  'Public Enemies',
#  'Ice Age: Dawn of the Dinosaurs',
#  'Mission, The',
#  "My Sister's Keeper",
#  'Nashville',
#  'Freedomland',
#  'Wackness, The',
#  'Punisher, The',
#  'American President, The',
#  'One Hour Photo',
#  'Starsky &amp; Hutch',
#  'Independence Day',
#  'Old School',
#  'Lazarus Effect, The',
#  'Focus',
#  'DUFF, The',
#  'McFarland, USA',
#  'Fifty Shades of Grey',
#  'Seventh Son',
#  'Jupiter Ascending',
#  'Project Almanac',
#  'Black Sea',
#  'Black or White',
#  'Oleanna',
#  'Pocahontas',
#  'Indiana Jones and the Last Crusade',
#  'Harsh Times',
#  'Prime',
#  'Doubt',
#  'North',
#  'Apocalypse Now',
#  'Phantom',
#  'Snitch',
#  'Good Day to Die Hard, A',
#  'Safe Haven',
#  'Beautiful Creatures',
#  'Identity Thief',
#  'Side Effects',
#  'Bullet to the Head',
#  'Warm Bodies',
#  'Parker',
#  'Reminiscence',
#  'Night House, The',
#  'Annette',
#  'Big Trouble in Little China',
#  'Respect',
#  'Free Guy',
#  'Suicide Squad, The',
#  'Nine Days',
#  'Vivo',
#  'Sweet November',
#  'Almost Famous',
#  'Diving Bell and the Butterfly, The',
#  'Ref, The',
#  'Girl on the Bridge, The (La Fille sur le pont)',
#  'Last Samurai, The',
#  'Dead Man',
#  'Woodsman, The',
#  'Here Comes the Boom',
#  'Sinister',
#  'Argo',
#  'Taken 2',
#  'V/H/S',
#  'Frankenweenie',
#  'Paperboy, The',
#  'Hotel Transylvania',
#  'Pitch Perfect',
#  'Looper',
#  'Celebration, The',
#  'Island, The',
#  'L.A. Confidential',
#  'One Missed Call',
#  "Charlotte's Web",
#  'Kung-Fu Hustle',
#  'American History X',
#  'Capturing the Friedmans',
#  'Wedding Crashers',
#  'Bourne Identity, The',
#  'Young @ Heart',
#  'Strangers, The',
#  'Madagascar',
#  'Fargo',
#  'Trigger Effect, The',
#  'Truman Show, The',
#  'Bourne Supremacy, The',
#  'Captain America',
#  'Smile',
#  'Blonde',
#  'Bandit',
#  "Don't Worry Darling",
#  'Avatar (2022 Re-Release)',
#  'Woman King, The',
#  'See How They Run',
#  'Pearl',
#  'Clerks III',
#  'Hannah Montana: The Movie',
#  'Scarface',
#  'Sin Nombre',
#  'Fast &amp; Furious',
#  'Gigantic',
#  'Sudden Impact',
#  'Adventureland',
#  '12 Rounds',
#  'Haunting in Connecticut, The',
#  'Monsters vs. Aliens',
#  'This Is Spinal Tap',
#  'Star Trek: Generations',
#  'Leatherheads',
#  'Love, Actually',
#  'Zathura',
#  'Curious Case of Benjamin Button, The',
#  'Gingerbread Man, The',
#  "Nobody's Fool",
#  'Rebecca',
#  'Honest Thief',
#  'Trial of the Chicago 7, The',
#  'Nocturne',
#  'War with Grandpa, The',
#  'Forty-Year-Old Version, The',
#  'Rainy Day in New York, A',
#  'Lie, The',
#  'Hocus Pocus',
#  'Star Trek: First Contact',
#  "Nim's Island",
#  'Christmas Story, A',
#  'Aristocrats, The',
#  'Last Chance Harvey',
#  'Celebrity',
#  "Cookie's Fortune",
#  'Quest for Camelot, The',
#  'Star Trek: Nemesis',
#  'Ruins, The',
#  'We Own the Night',
#  'Mad Max: Beyond Thunderdome',
#  'Promotion, The',
#  'Mummy, The: Tomb of the Dragon Emperor',
#  'Brotherhood of the Wolf',
#  'Searching for Bobby Fischer',
#  'Zodiac',
#  'Little Miss Sunshine',
#  'Hilary and Jackie',
#  'Elegy',
#  'Zombieland: Double Tap',
#  'Maleficent: Mistress of Evil',
#  'Only Yesterday',
#  'Addams Family, The',
#  'Mary',
#  'Gemini Man',
#  'Laundromat, The',
#  'If Looks Could Kill',
#  'Joker',
#  'Day Shall Come, The',
#  'Speed',
#  'Alien Resurrection',
#  'Infamous',
#  'Squid and the Whale, The',
#  'Pi',
#  'Chicken Run',
#  'Miracle',
#  'Star Wars Episode V: The Empire Strikes Back',
#  'Punisher: War Zone',
#  'Get Shorty',
#  'Good Year, A',
#  'North Country',
#  'Reader, The',
#  'Frighteners, The',
#  'I Heart Huckabees',
#  'Rendition',
#  'Running with Scissors',
#  "My Best Friend's Girl",
#  'Lost in Space',
#  'Big Lebowski, The',
#  'Everest',
#  'Maze Runner: The Scorch Trials',
#  'Black Mass',
#  'Visit, The',
#  'Walk in the Woods, A',
#  'We Are Your Friends',
#  'Mistress America',
#  'No Escape',
#  'Sinister 2',
#  'Go Now',
#  'Sicko',
#  'Superman',
#  'Wedding Date, The',
#  'Dead Man Walking',
#  'Free Willy',
#  'American Werewolf in Paris, An',
#  'In the Name of the King: A Dungeon Seige Tale',
#  'Simpsons Movie, The',
#  'Shallows, The',
#  'Central Intelligence',
#  'Finding Dory',
#  'Warcraft',
#  'Now You See Me 2',
#  'Conjuring 2, The',
#  'Popstar: Never Stop Never Stopping',
#  'Me Before You',
#  'Alice through the Looking Glass',
#  'X-Men: Apocalypse',
#  'Joy Ride',
#  'Phantom of the Opera, The',
#  'City of Lost Children, The',
#  'Teeth',
#  'Charlie and the Chocolate Factory',
#  'Synecdoche, New York',
#  'Good Girl, The',
#  'Mulholland Falls',
#  'Tomb Raider: The Cradle of Life',
#  'Larry Crowne',
#  'Transformers 3: Dark of the Moon',
#  'Cars 2',
#  'Bad Teacher',
#  'Green Lantern',
#  'Beginners',
#  'Super 8',
#  'Submarine',
#  'Tree of Life, The',
#  'X-Men: First Class',
#  'Gods and Monsters',
#  'Star Trek III: The Search for Spock',
#  'Cat in the Hat, The',
#  'Santa Clause, The',
#  'Walk the Line',
#  'Tale of Despereaux, The',
#  'Sleepless in Seattle',
#  'What Women Want',
#  "Mary Shelly's Frankenstein",
#  'Star Trek IV: The Voyage Home',
#  'Last House on the Left, The',
#  'First Blood',
#  'Watchmen',
#  'Everlasting Moments',
#  'Body Heat',
#  'Echelon Conspiracy',
#  'Two Lovers',
#  'Crossing Over',
#  'Ordinary People',
#  '40-Year-Old Virgin, The',
#  'Live Free or Die Hard',
#  'Number 23, The',
#  'Love Guru, The',
#  'Ghost Town',
#  'My Father the Hero',
#  'Feast of July',
#  'Van Helsing',
#  'Lords of Dogtown',
#  'Mixed Nuts',
#  'Othello',
#  'Swing Kids',
#  "Ocean's Thirteen",
#  'Catwoman',
#  'Mindhunters',
#  'Words, The',
#  'Bachelorette',
#  'Premium Rush',
#  'About Cherry',
#  'Hit &amp; Run',
#  'Sparkle',
#  'Expendables 2, The',
#  'Compliance',
#  'Cosmopolis',
#  'Celeste and Jesse Forever',
#  'Freedom Writers',
#  "Pan's Labyrinth",
#  'Monster House',
#  'Two for the Money',
#  'Arrival, The',
#  'Grace Is Gone',
#  'Fahrenheit 9/11',
#  'My Super Ex-Girlfriend',
#  'Unleashed',
#  'Water Diviner, The',
#  'Age of Adaline, The',
#  'Child 44',
#  'Clouds of Sils Maria, The',
#  'Unfriended',
#  'Ex Machina',
#  'True Story',
#  'Longest Ride, The',
#  "While We're Young",
#  'Furious Seven',
#  'Life During Wartime',
#  'Salt',
#  'Father of My Children, The',
#  'Inception',
#  "Sorcerer's Apprentice, The",
#  'Despicable Me',
#  'Predators',
#  'Girl Who Played with Fire, The',
#  'Let it Rain',
#  'Twilight: Eclipse',
#  'Death Sentence',
#  'Stranger than Fiction',
#  '16 Blocks',
#  'Hamlet 2',
#  'Funny Bones',
#  "Charlie Wilson's War",
#  'Falling Down',
#  'Eagle vs. Shark',
#  'Dreamgirls',
#  'House of Tomorrow, The',
#  'Solo: A Star Wars Story',
#  'Book Club',
#  'Carter and June',
#  'Deadpool 2',
#  'Disobedience',
#  'Life of the Party',
#  'Terminal',
#  'Bad Samaritan',
#  'Brothers',
#  'Me and Orson Welles',
#  'Old Dogs',
#  'Fantastic Mr. Fox',
#  'Road, The',
#  'Twilight: New Moon',
#  'Blind Side, The',
#  'Bad Lieutenant: Port of Call New Orleans',
#  '2012',
#  '8 1/2 Women',
#  'Bowling for Columbine',
#  'Murder at 1600',
#  'American Gangster',
#  'Proof',
#  'Hellboy II: The Golden Army',
#  'In the Line of Fire',
#  'How to Be Single',
#  'Deadpool',
#  'Pride and Prejudice and Zombies',
#  'Hail, Caesar!',
#  'Kung Fu Panda 3',
#  'Finest Hours, The',
#  'Son of Saul',
#  '5th Wave, The',
#  '13 Hours: The Secret Soldiers of Benghazi',
#  'Anomalisa',
#  'Pompeii',
#  "Winter's Tale",
#  'About Last Night',
#  'Lego Movie, The',
#  'Kids for Cash',
#  'Monuments Men, The',
#  'Labor Day',
#  'That Awkward Moment',
#  'I, Frankenstein',
#  'Everything Is Illuminated',
#  'Bring It On',
#  'Save the Last Dance',
#  'Lars and the Real Girl',
#  'Baby Mama',
#  'We Are Marshall',
#  'Flightplan',
#  'Dumb and Dumberer',
#  'Pitch Black',
#  'Grudge Match',
#  'Saving Mr. Banks',
#  'Anchorman 2: The Legend Continues',
#  'American Hustle',
#  'Hobbit, The: The Desolation of Smaug',
#  'Inside Llewyn Davis',
#  'Out of the Furnace',
#  'Oldboy (2013)',
#  'Homefront',
#  'Frozen',
#  'Mortal Engines',
#  'Mary Queen of Scots',
#  'Once Upon a Deadpool',
#  'Spider-Man: Into the Spider-Verse',
#  'Roma',
#  'Shoplifters',
#  'Vox Lux',
#  'Skin I Live In, The',
#  'Favourite, The',
#  'Red Riding: 1974',
#  'Shutter Island',
#  'Ghost Writer, The',
#  "Valentine's Day",
#  'Wolfman, The',
#  'Fish Tank',
#  'Dear John',
#  'From Paris with Love',
#  'Go',
#  'Vantage Point',
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'Hitch',
#  'Soul Men',
#  'Crocodile Dundee',
#  'Analyze That',
#  'Meet the Fockers',
#  'Drillbit Taylor',
#  '21',
#  'Big Hero 6',
#  'Interstellar',
#  'Nightcrawler',
#  'Before I Go to Sleep',
#  'Good Lie, The',
#  'Whiplash',
#  'John Wick',
#  'Fury',
#  'Birdman',
#  'Book of Life, The',
#  '49 Up',
#  'Nacho Libre',
#  'Prelude to a Kiss',
#  'Sling Blade',
#  'Magdalene Sisters, The',
#  'Toy Story 2',
#  "First Wives' Club, The",
#  'Last Legion, The',
#  'Deliver Us From Evil',
#  'Show Me Love',
#  'Reservation Road',
#  'Blood and Chocolate',
#  'Scary Movie 4',
#  'Message in a Bottle',
#  'Professional, The (Leon)',
#  'Together',
#  'Reindeer Games',
#  'Spider-Man Homecoming',
#  'Despicable Me 3',
#  'Beguiled, The',
#  'Journey, The',
#  'Okja',
#  'Baby Driver',
#  'Transformers: The Last Knight',
#  'Cars 3',
#  'Rough Night',
#  'Book of Henry, The',
#  'Easy A',
#  'Town, The',
#  'Flipped',
#  'Heartbreaker',
#  'Virginity Hit, The',
#  'Disappearance of Alice Creed, The',
#  'Machete',
#  'American, The',
#  'Mesrine: Public Enemy No. 1',
#  'Going the Distance',
#  'Hurt Locker, The',
#  'Transformers: Revenge of the Fallen',
#  'Cheri',
#  'About Last Night...',
#  'Whatever Works',
#  'Stand By Me',
#  'Year One',
#  'Proposal, The',
#  'Taking of Pelham 123, The',
#  'Imagine That',
#  'Match Point',
#  'Inside Deep Throat',
#  'Payback',
#  'Hollow Man',
#  'Sommersby',
#  'Dear God',
#  'Because I Said So',
#  'Street Kings',
#  'Downfall',
#  'Man, The',
#  'Measure of a Man',
#  'RBG',
#  'Splendor',
#  'Anon',
#  'Overboard',
#  'Tully',
#  'Duck Butter',
#  'Supercon',
#  'Avengers: Infinity War',
#  'Happy-Go-Lucky',
#  'Mulholland Drive',
#  'Mask, The',
#  'Glory',
#  'Rock, The',
#  "Kickin' It Old Skool",
#  'Glengarry Glen Ross',
#  'Tideland',
#  'City of Ember',
#  'Amores Perros',
#  'Get Duked!',
#  ...]

# %% [markdown]
# #### 2.3.2. Dropping Movies with Duplicate Names
#
# Finally, use this `title` list from 2.3.1 to drop all rows that correspond to a `title` that had more than one row assigned to it. (Or in other words drop the movies that we considered "duplicates").
#
# How many additional rows did you drop?

# %%
def process(row):
    current_title = row['title']
    if current_title in Titles:
        return True
    else:
        return False
df_prean['Title Exists'] = df_prean.apply(process, axis=1)
df_prean
# Out:
# C:\Users\samma\AppData\Local\Temp\ipykernel_17364\3152709615.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prean['Title Exists'] = df_prean.apply(process, axis=1)
#                      title  release_date  \
# 0      Terms of Endearment        1983.0
# 1                     1917        2019.0
# 2        Spies in Disguise        2019.0
# 3               Just Mercy        2019.0
# 4             Little Women        2019.0
# ...                    ...           ...
# 3985  Music of Chance, The        1993.0
# 3986           Ultraviolet        2006.0
# 3987               Speed 2        1997.0
# 3988               Ex, The        2007.0
# 3989                 Venus        2006.0
#
#                                                    cast  Title Exists
# 0     Shirley MacLaine, Debra Winger, Jack Nicholson...          True
# 1                   George MacKay, Dean-Charles Chapman          True
# 2     Will Smith, Tom Holland, Rashida Jones, Ben Me...          True
# 3     Michael B. Jordan, Jamie Foxx, Brie Larson, Ti...          True
# 4     Saoirse Ronan, Chris Cooper, Louis Garrel, Jam...         False
# ...                                                 ...           ...
# 3985  Mandy Patinkin, James Spader, M. Emmet Walsh, ...          True
# 3986  Milla Jovovich, Cameron Bright, Nick Chinlund,...          True
# 3987  Sandra Bullock, Jason Patric, Willem Dafoe, Te...          True
# 3988  Zach Braff, Amanda Peet, Jason Bateman, Charle...          True
# 3989  Peter O'Toole, Jodie Whittaker, Leslie Phillip...          True
#
# [3694 rows x 4 columns]

# %%
title_filtered_df = df_prean[df_prean['Title Exists'] != False]
title_filtered_df = title_filtered_df.drop('Title Exists', axis=1).reset_index()
title_filtered_df
# Out:
#       index                 title  release_date  \
# 0         0   Terms of Endearment        1983.0
# 1         1                  1917        2019.0
# 2         2     Spies in Disguise        2019.0
# 3         3            Just Mercy        2019.0
# 4         5             Bombshell        2019.0
# ...     ...                   ...           ...
# 3545   3985  Music of Chance, The        1993.0
# 3546   3986           Ultraviolet        2006.0
# 3547   3987               Speed 2        1997.0
# 3548   3988               Ex, The        2007.0
# 3549   3989                 Venus        2006.0
#
#                                                    cast
# 0     Shirley MacLaine, Debra Winger, Jack Nicholson...
# 1                   George MacKay, Dean-Charles Chapman
# 2     Will Smith, Tom Holland, Rashida Jones, Ben Me...
# 3     Michael B. Jordan, Jamie Foxx, Brie Larson, Ti...
# 4     Charlize Theron, Nicole Kidman, Margot Robbie,...
# ...                                                 ...
# 3545  Mandy Patinkin, James Spader, M. Emmet Walsh, ...
# 3546  Milla Jovovich, Cameron Bright, Nick Chinlund,...
# 3547  Sandra Bullock, Jason Patric, Willem Dafoe, Te...
# 3548  Zach Braff, Amanda Peet, Jason Bateman, Charle...
# 3549  Peter O'Toole, Jodie Whittaker, Leslie Phillip...
#
# [3550 rows x 4 columns]

# %%
row_num = len(df_prean) - len(title_filtered_df)
row_num
# Out:
# 144

# %% [markdown]
# ## 3. Merging the Two Dataframes
#
# We'd next like to merge these two cleaned dataframes on the `Name` (ie. `title`) of the film/series.
#
# ### 3.1. Outer Join Merge
#
# First, it's possible that not every `Name` in the ratings dataframe may have a match to every `title` in the actors dataframe, and vice versa. To help us assess how many movies in each dataframe don't have a match, let's first perform an **outer join** merge of the two dataframes on the `Name` (ie. `title`) of the movie/film.

# %%
merge_df = pd.merge(filtered_df, title_filtered_df,
                    how='outer',
                    left_on=['Name'],
                    right_on=['title'])
merge_df
# Out:
#       index_x                         Name  Rate    Date    Type  index_y  \
# 0         0.0               No Time to Die   7.6  2021.0    Film    155.0
# 1         2.0    The Many Saints of Newark   6.4  2021.0    Film      NaN
# 2         3.0  Venom: Let There Be Carnage   6.4  2021.0    Film    157.0
# 3         5.0                    Ted Lasso   8.8  2021.0  Series      NaN
# 4         6.0                     Free Guy   7.3  2021.0    Film    625.0
# ...       ...                          ...   ...     ...     ...      ...
# 6055      NaN                          NaN   NaN     NaN     NaN   3985.0
# 6056      NaN                          NaN   NaN     NaN     NaN   3986.0
# 6057      NaN                          NaN   NaN     NaN     NaN   3987.0
# 6058      NaN                          NaN   NaN     NaN     NaN   3988.0
# 6059      NaN                          NaN   NaN     NaN     NaN   3989.0
#
#                             title  release_date  \
# 0                  No Time to Die        2021.0
# 1                             NaN           NaN
# 2     Venom: Let There Be Carnage        2021.0
# 3                             NaN           NaN
# 4                        Free Guy        2021.0
# ...                           ...           ...
# 6055         Music of Chance, The        1993.0
# 6056                  Ultraviolet        2006.0
# 6057                      Speed 2        1997.0
# 6058                      Ex, The        2007.0
# 6059                        Venus        2006.0
#
#                                                    cast
# 0     Daniel Craig, Jeffrey Wright, Lea Seydoux, Ram...
# 1                                                   NaN
# 2     Tom Hardy, Woody Harrelson, Michelle Williams,...
# 3                                                   NaN
# 4     Ryan Reynolds, Jodie Comer, Taika Waititi, Joe...
# ...                                                 ...
# 6055  Mandy Patinkin, James Spader, M. Emmet Walsh, ...
# 6056  Milla Jovovich, Cameron Bright, Nick Chinlund,...
# 6057  Sandra Bullock, Jason Patric, Willem Dafoe, Te...
# 6058  Zach Braff, Amanda Peet, Jason Bateman, Charle...
# 6059  Peter O'Toole, Jodie Whittaker, Leslie Phillip...
#
# [6060 rows x 9 columns]

# %% [markdown]
# ### 3.2. Rating Dataset `Names` with No Match
#
# First, how many movie `Names` in our ratings dataframe did not have a match with a movie `title` in our actors dataframe?
#
# Hint: The **.isna().sum()** functions might help you.

# %%
merge_df.isna().sum()
# Out:
# index_x         2627
# Name            2627
# Rate            2627
# Date            2627
# Type            2627
# index_y         2510
# title           2510
# release_date    2510
# cast            2510
# dtype: int64

# %% [markdown]
# 2627 movie Names did not match with title in actors

# %% [markdown]
# ### 3.3. Actor Dataset `titles` with No Match
#
# Next, how many movie `titles` in our actors dataframe did not have a match with a movie `Name` in our ratings dataframe?
#
# Hint: The **.isna().sum()** functions might help you.

# %%
merge_df.isna().sum()
# Out:
# index_x         2627
# Name            2627
# Rate            2627
# Date            2627
# Type            2627
# index_y         2510
# title           2510
# release_date    2510
# cast            2510
# dtype: int64

# %% [markdown]
# 2510 titles do not match with movie Names in our ratings dataframe

# %% [markdown]
# ### 3.4. Inner Join Merge
#
# Let's next perform an **inner join** merge of ratings dataframe and the actors dataframe on the `Name` (ie. `title`) of the movie/film.

# %%
inner_merge_df = pd.merge(filtered_df, title_filtered_df,
                    how='inner',
                    left_on=['Name'],
                    right_on=['title'])
inner_merge_df
# Out:
#      index_x                                       Name  Rate  Date  Type  \
# 0          0                             No Time to Die   7.6  2021  Film
# 1          3                Venom: Let There Be Carnage   6.4  2021  Film
# 2          6                                   Free Guy   7.3  2021  Film
# 3         19                                Black Widow   6.8  2021  Film
# 4         22  Shang-Chi and the Legend of the Ten Rings   7.9  2021  Film
# ..       ...                                        ...   ...   ...   ...
# 918     3841                                   17 Again   6.4  2009  Film
# 919     3847                              Freaky Friday   6.2  2003  Film
# 920     3867                               Lost Highway   7.6  1997  Film
# 921     3873                                 Sinister 2   5.3  2015  Film
# 922     3876                                        Mud   7.4  2012  Film
#
#      index_y                                      title  release_date  \
# 0        155                             No Time to Die        2021.0
# 1        157                Venom: Let There Be Carnage        2021.0
# 2        625                                   Free Guy        2021.0
# 3       3307                                Black Widow        2021.0
# 4       3656  Shang-Chi and the Legend of the Ten Rings        2021.0
# ..       ...                                        ...           ...
# 918     3336                                   17 Again        2009.0
# 919     2104                              Freaky Friday        2003.0
# 920     3715                               Lost Highway        1997.0
# 921      789                                 Sinister 2        2015.0
# 922     3519                                        Mud        2013.0
#
#                                                   cast
# 0    Daniel Craig, Jeffrey Wright, Lea Seydoux, Ram...
# 1    Tom Hardy, Woody Harrelson, Michelle Williams,...
# 2    Ryan Reynolds, Jodie Comer, Taika Waititi, Joe...
# 3    Scarlett Johansson, Florence Pugh, Rachel Weis...
# 4    Simu Liu, Awkwafina, Meng’er Zhang, Tony Leung...
# ..                                                 ...
# 918  Zac Efron, Leslie Mann, Thomas Lennon, Matthew...
# 919  Jamie Lee Curtis, Lindsay Lohan, Ryan Malgarin...
# 920  Bill Pullman, Patricia Arquette, Balthazar Get...
# 921  James Ransone, Shannyn Sossamon, Robert Daniel...
# 922  Matthew McConaughey, Paul Sparks, Michael Shan...
#
# [923 rows x 9 columns]

# %% [markdown]
# ### 3.5. Rating and Actor Dataset `Name`(`title`) Matches
#
# How many `Name`(`title`) matches were there in the rating and actor dataset?

# %%
len(inner_merge_df)
# Out:
# 923

# %% [markdown]
# ### 3.6. Representativeness of the Merged Dataset
#
# Would you be comfortable stating that this new joined dataset is *representative* of the ratings of all the POPULAR films/series that were listed in our original `imdb.csv` file? Why or why not?

# %% [markdown]
# No they're representative of the movies which are also present in the ReelView dataset, which only contain a small portion of the entire IMDB list.

# %% [markdown]
# ## 4. Creating Famous Actor Variables
#
# ### 4.1. Famous Actor Variable 1: CHOOSE YOUR OWN
#
# Use this merged dataframe from #3.4 to create a new variable that indicates whether or not a famous actor was in the film. You can choose your own famous actor. Make sure that it's an actor in at least one film in this merged dataframe from #3.4.

# %%
inner_merge_df['ScarJo'] = inner_merge_df['cast'].apply(lambda x: ('scarlett johansson' in x.lower()))
inner_merge_df
# Out:
#      index_x                                       Name  Rate  Date  Type  \
# 0          0                             No Time to Die   7.6  2021  Film
# 1          3                Venom: Let There Be Carnage   6.4  2021  Film
# 2          6                                   Free Guy   7.3  2021  Film
# 3         19                                Black Widow   6.8  2021  Film
# 4         22  Shang-Chi and the Legend of the Ten Rings   7.9  2021  Film
# ..       ...                                        ...   ...   ...   ...
# 918     3841                                   17 Again   6.4  2009  Film
# 919     3847                              Freaky Friday   6.2  2003  Film
# 920     3867                               Lost Highway   7.6  1997  Film
# 921     3873                                 Sinister 2   5.3  2015  Film
# 922     3876                                        Mud   7.4  2012  Film
#
#      index_y                                      title  release_date  \
# 0        155                             No Time to Die        2021.0
# 1        157                Venom: Let There Be Carnage        2021.0
# 2        625                                   Free Guy        2021.0
# 3       3307                                Black Widow        2021.0
# 4       3656  Shang-Chi and the Legend of the Ten Rings        2021.0
# ..       ...                                        ...           ...
# 918     3336                                   17 Again        2009.0
# 919     2104                              Freaky Friday        2003.0
# 920     3715                               Lost Highway        1997.0
# 921      789                                 Sinister 2        2015.0
# 922     3519                                        Mud        2013.0
#
#                                                   cast  ScarJo
# 0    Daniel Craig, Jeffrey Wright, Lea Seydoux, Ram...   False
# 1    Tom Hardy, Woody Harrelson, Michelle Williams,...   False
# 2    Ryan Reynolds, Jodie Comer, Taika Waititi, Joe...   False
# 3    Scarlett Johansson, Florence Pugh, Rachel Weis...    True
# 4    Simu Liu, Awkwafina, Meng’er Zhang, Tony Leung...   False
# ..                                                 ...     ...
# 918  Zac Efron, Leslie Mann, Thomas Lennon, Matthew...   False
# 919  Jamie Lee Curtis, Lindsay Lohan, Ryan Malgarin...   False
# 920  Bill Pullman, Patricia Arquette, Balthazar Get...   False
# 921  James Ransone, Shannyn Sossamon, Robert Daniel...   False
# 922  Matthew McConaughey, Paul Sparks, Michael Shan...   False
#
# [923 rows x 10 columns]

# %% [markdown]
# ### 4.2. Famous Actor Variable 2: CHOOSE YOUR OWN
#
# Use this merged dataframe from #3.4 to create a new variable that indicates whether or not a famous actor was in the film. You can choose your own famous actor. Make sure that it's an actor in at least one film in this merged dataframe from #3.4.

# %%
inner_merge_df['RyRo'] = inner_merge_df['cast'].apply(lambda x: ('ryan reynolds' in x.lower()))
inner_merge_df
# Out:
#      index_x                                       Name  Rate  Date  Type  \
# 0          0                             No Time to Die   7.6  2021  Film
# 1          3                Venom: Let There Be Carnage   6.4  2021  Film
# 2          6                                   Free Guy   7.3  2021  Film
# 3         19                                Black Widow   6.8  2021  Film
# 4         22  Shang-Chi and the Legend of the Ten Rings   7.9  2021  Film
# ..       ...                                        ...   ...   ...   ...
# 918     3841                                   17 Again   6.4  2009  Film
# 919     3847                              Freaky Friday   6.2  2003  Film
# 920     3867                               Lost Highway   7.6  1997  Film
# 921     3873                                 Sinister 2   5.3  2015  Film
# 922     3876                                        Mud   7.4  2012  Film
#
#      index_y                                      title  release_date  \
# 0        155                             No Time to Die        2021.0
# 1        157                Venom: Let There Be Carnage        2021.0
# 2        625                                   Free Guy        2021.0
# 3       3307                                Black Widow        2021.0
# 4       3656  Shang-Chi and the Legend of the Ten Rings        2021.0
# ..       ...                                        ...           ...
# 918     3336                                   17 Again        2009.0
# 919     2104                              Freaky Friday        2003.0
# 920     3715                               Lost Highway        1997.0
# 921      789                                 Sinister 2        2015.0
# 922     3519                                        Mud        2013.0
#
#                                                   cast  ScarJo   RyRo
# 0    Daniel Craig, Jeffrey Wright, Lea Seydoux, Ram...   False  False
# 1    Tom Hardy, Woody Harrelson, Michelle Williams,...   False  False
# 2    Ryan Reynolds, Jodie Comer, Taika Waititi, Joe...   False   True
# 3    Scarlett Johansson, Florence Pugh, Rachel Weis...    True  False
# 4    Simu Liu, Awkwafina, Meng’er Zhang, Tony Leung...   False  False
# ..                                                 ...     ...    ...
# 918  Zac Efron, Leslie Mann, Thomas Lennon, Matthew...   False  False
# 919  Jamie Lee Curtis, Lindsay Lohan, Ryan Malgarin...   False  False
# 920  Bill Pullman, Patricia Arquette, Balthazar Get...   False  False
# 921  James Ransone, Shannyn Sossamon, Robert Daniel...   False  False
# 922  Matthew McConaughey, Paul Sparks, Michael Shan...   False  False
#
# [923 rows x 11 columns]

# %% [markdown]
# ### 4.3. Actor Rating Comparison
#
# Create two boxplots.
# 1. One boxplot should show the ratings distribution of films with your first actor in the cast.
# 2. One boxplot should show the ratings distribution of films with your second actor in the cast.
# 3. Does one of these actor's movies have a comparatively much higher distribution of ratings than the other actor? Explain.

# %%
sns.boxplot(x='ScarJo', y='Rate', data=inner_merge_df)
# Out:
# <Axes: xlabel='ScarJo', ylabel='Rate'>

# %%
sns.boxplot(x='RyRo', y='Rate', data=inner_merge_df)
# Out:
# <Axes: xlabel='RyRo', ylabel='Rate'>

# %% [markdown]
# When comparing the ratings of Scarlett Johansson and Ryan Reynolds there is not a strong association between having either of the actors and ratings. When comparing the two actors, Scarlett has a stronger association with rating than Ryan Reynolds. The distribution of their ratings are about the same, with Scarlett's on average about 0.5 points higher.

# %% [markdown]
# ### Contribution Report
# These contribution reports should be included in all group lab assignments. In this contribution report below you should list of the following:
# 1. Names of each team member.
# 2. Contributions of each team member to report.
#
# *For example:*
#
# *<u>Teammates:</u>*
#
# *1. John Smith: did number 1,2 and 3*
#
# *2. Jane Doe: did number 4, and 5*
#
# 1. Sammy Haskel did numbers 1,2
# 2. Isabella did numbers 1,2
# 3. Syed Ammar Raza did numbers 2,3
# 4. Ava Zheng did numbers 3,4
